# %%
# %run StatTest2_WithSimulation_Setup.ipynb

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = ["NY"]
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
df2 = create_df2(states, dfs)

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 202300.000

# %%
beta1, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2)
# Out:
# k = 79
# test_stat at this k = 0.15280
#
# At the point of maximum difference with beta = 202300:
# P(|d_i|<v) = 0.7848
# P(|N(0,max_beta^2)|<v) = 0.4046
# Difference = 0.3802
#
#
#
#
# At the point of maximum difference with beta = 192300:
# P(|d_i|<v) = 0.6709
# P(|N(0,max_beta^2)|<v) = 0.3055
# Difference = 0.3654
#
#
#
#
# At the point of maximum difference with beta = 182300:
# P(|d_i|<v) = 0.6709
# P(|N(0,max_beta^2)|<v) = 0.3214
# Difference = 0.3495
#
#
#
#
# At the point of maximum difference with beta = 172300:
# P(|d_i|<v) = 0.6709
# P(|N(0,max_beta^2)|<v) = 0.3389
# Difference = 0.3320
#
#
#
#
# At the point of maximum difference with beta = 162300:
# P(|d_i|<v) = 0.6709
# P(|N(0,max_beta^2)|<v) = 0.3583
# Difference = 0.3126
#
#
#
#
# At the point of maximum difference with beta = 152300:
# P(|d_i|<v) = 0.6709
# P(|N(0,max_beta^2)|<v) = 0.3801
# Difference = 0.2908
#
#
#
#
# At the point of maximum difference with beta = 142300:
# P(|d_i|<v) = 0.6709
# P(|N(0,max_beta^2)|<v) = 0.4044
# Difference = 0.2665
#
#
#
#
# At the point of maximum difference with beta = 132300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.2478
# Difference = 0.2459
#
#
#
#
# At the point of maximum difference with beta = 122300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.2673
# Difference = 0.2264
#
#
#
#
# At the point of maximum difference with beta = 112300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.2901
# Difference = 0.2036
#
#
#
#
# At the point of maximum difference with beta = 102300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3169
# Difference = 0.1767
#
#
#
#
# At the point of maximum difference with beta = 102300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3169
# Difference = 0.1767
#
#
#
#
# At the point of maximum difference with beta = 102200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3172
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 102100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3175
# Difference = 0.1762
#
#
#
#
# At the point of maximum difference with beta = 102000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3178
# Difference = 0.1759
#
#
#
#
# At the point of maximum difference with beta = 101900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3181
# Difference = 0.1756
#
#
#
#
# At the point of maximum difference with beta = 101800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3184
# Difference = 0.1753
#
#
#
#
# At the point of maximum difference with beta = 101700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3187
# Difference = 0.1750
#
#
#
#
# At the point of maximum difference with beta = 101600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3190
# Difference = 0.1747
#
#
#
#
# At the point of maximum difference with beta = 101500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3193
# Difference = 0.1744
#
#
#
#
# At the point of maximum difference with beta = 101400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3196
# Difference = 0.1741
#
#
#
#
# At the point of maximum difference with beta = 101300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3199
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 101200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3202
# Difference = 0.1735
#
#
#
#
# At the point of maximum difference with beta = 101100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3205
# Difference = 0.1732
#
#
#
#
# At the point of maximum difference with beta = 101000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3208
# Difference = 0.1729
#
#
#
#
# At the point of maximum difference with beta = 100900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3211
# Difference = 0.1726
#
#
#
#
# At the point of maximum difference with beta = 100800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3214
# Difference = 0.1723
#
#
#
#
# At the point of maximum difference with beta = 100700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3217
# Difference = 0.1720
#
#
#
#
# At the point of maximum difference with beta = 100600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3220
# Difference = 0.1717
#
#
#
#
# At the point of maximum difference with beta = 100500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3223
# Difference = 0.1714
#
#
#
#
# At the point of maximum difference with beta = 100400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3226
# Difference = 0.1711
#
#
#
#
# At the point of maximum difference with beta = 100300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3229
# Difference = 0.1708
#
#
#
#
# At the point of maximum difference with beta = 100200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3232
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 100100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3235
# Difference = 0.1702
#
#
#
#
# At the point of maximum difference with beta = 100000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3238
# Difference = 0.1699
#
#
#
#
# At the point of maximum difference with beta = 99900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3241
# Difference = 0.1696
#
#
#
#
# At the point of maximum difference with beta = 99800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3244
# Difference = 0.1692
#
#
#
#
# At the point of maximum difference with beta = 99700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3247
# Difference = 0.1689
#
#
#
#
# At the point of maximum difference with beta = 99600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1686
#
#
#
#
# At the point of maximum difference with beta = 99500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3253
# Difference = 0.1683
#
#
#
#
# At the point of maximum difference with beta = 99400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3257
# Difference = 0.1680
#
#
#
#
# At the point of maximum difference with beta = 99300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3260
# Difference = 0.1677
#
#
#
#
# At the point of maximum difference with beta = 99200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3263
# Difference = 0.1674
#
#
#
#
# At the point of maximum difference with beta = 99100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3266
# Difference = 0.1671
#
#
#
#
# At the point of maximum difference with beta = 99000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3269
# Difference = 0.1668
#
#
#
#
# At the point of maximum difference with beta = 98900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3272
# Difference = 0.1665
#
#
#
#
# At the point of maximum difference with beta = 98800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3275
# Difference = 0.1662
#
#
#
#
# At the point of maximum difference with beta = 98700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3278
# Difference = 0.1658
#
#
#
#
# At the point of maximum difference with beta = 98600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3281
# Difference = 0.1655
#
#
#
#
# At the point of maximum difference with beta = 98500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3285
# Difference = 0.1652
#
#
#
#
# At the point of maximum difference with beta = 98400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.1649
#
#
#
#
# At the point of maximum difference with beta = 98300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3291
# Difference = 0.1646
#
#
#
#
# At the point of maximum difference with beta = 98200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3294
# Difference = 0.1643
#
#
#
#
# At the point of maximum difference with beta = 98100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3297
# Difference = 0.1640
#
#
#
#
# At the point of maximum difference with beta = 98000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3300
# Difference = 0.1636
#
#
#
#
# At the point of maximum difference with beta = 97900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3304
# Difference = 0.1633
#
#
#
#
# At the point of maximum difference with beta = 97800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3307
# Difference = 0.1630
#
#
#
#
# At the point of maximum difference with beta = 97700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3310
# Difference = 0.1627
#
#
#
#
# At the point of maximum difference with beta = 97600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3313
# Difference = 0.1624
#
#
#
#
# At the point of maximum difference with beta = 97500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3316
# Difference = 0.1620
#
#
#
#
# At the point of maximum difference with beta = 97400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3319
# Difference = 0.1617
#
#
#
#
# At the point of maximum difference with beta = 97300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3323
# Difference = 0.1614
#
#
#
#
# At the point of maximum difference with beta = 97200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3326
# Difference = 0.1611
#
#
#
#
# At the point of maximum difference with beta = 97100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3329
# Difference = 0.1608
#
#
#
#
# At the point of maximum difference with beta = 97000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3332
# Difference = 0.1604
#
#
#
#
# At the point of maximum difference with beta = 96900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3336
# Difference = 0.1601
# At the point of maximum difference with beta = 96800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3339
# Difference = 0.1598
#
#
#
#
# At the point of maximum difference with beta = 96700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3342
# Difference = 0.1595
#
#
#
#
# At the point of maximum difference with beta = 96600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3345
# Difference = 0.1591
#
#
#
#
# At the point of maximum difference with beta = 96500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3349
# Difference = 0.1588
#
#
#
#
# At the point of maximum difference with beta = 96400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3352
# Difference = 0.1585
#
#
#
#
# At the point of maximum difference with beta = 96300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3355
# Difference = 0.1582
#
#
#
#
# At the point of maximum difference with beta = 96200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3358
# Difference = 0.1578
#
#
#
#
# At the point of maximum difference with beta = 96100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3362
# Difference = 0.1575
#
#
#
#
# At the point of maximum difference with beta = 96000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3365
# Difference = 0.1572
#
#
#
#
# At the point of maximum difference with beta = 95900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3368
# Difference = 0.1569
#
#
#
#
# At the point of maximum difference with beta = 95800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1565
#
#
#
#
# At the point of maximum difference with beta = 95700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3375
# Difference = 0.1562
#
#
#
#
# At the point of maximum difference with beta = 95600:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3378
# Difference = 0.1559
#
#
#
#
# At the point of maximum difference with beta = 95500:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3381
# Difference = 0.1555
#
#
#
#
# At the point of maximum difference with beta = 95400:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3385
# Difference = 0.1552
#
#
#
#
# At the point of maximum difference with beta = 95300:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3388
# Difference = 0.1549
#
#
#
#
# At the point of maximum difference with beta = 95200:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3391
# Difference = 0.1545
#
#
#
#
# At the point of maximum difference with beta = 95100:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3395
# Difference = 0.1542
#
#
#
#
# At the point of maximum difference with beta = 95000:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3398
# Difference = 0.1539
#
#
#
#
# At the point of maximum difference with beta = 94900:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3401
# Difference = 0.1535
#
#
#
#
# At the point of maximum difference with beta = 94800:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3405
# Difference = 0.1532
#
#
#
#
# At the point of maximum difference with beta = 94700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3408
# Difference = 0.1529

# %%
beta1 = beta1+100

theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 94700
# Number of T/sqrt(n) above 2 stds: 14
# Proportion of T/sqrt(n) above 2 stds: 0.177
# P value = 0.000002

# %%
df3 = create_df3(states, dfs)

# %%
ratios_c = create_simulation(df3, beta1 - 10000)
ratios_c2 = create_simulation(df3, beta1)
ratios_c3 = create_simulation(df3, beta1 + 10000)

# %%
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta1 - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta1))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta1 + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (states, len(df2)))
plt.legend()

# %%
run_test_against_simulation(df2, beta1, ratios2)
# Out:
# k = 79
# test_stat at this k = 0.15280
#
# At the point of maximum difference with beta = 94700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3408
# Difference = 0.1709
#
#
#
#
# At the point of maximum difference with beta = 94700:
# P(|d_i|<v) = 0.4937
# P(|N(0,max_beta^2)|<v) = 0.3408
# Difference = 0.1734
# (94600, 621)

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 94700
# Number of T/sqrt(n) above 2 stds: 14
# Proportion of T/sqrt(n) above 2 stds: 0.177
# P value = 0.000002
