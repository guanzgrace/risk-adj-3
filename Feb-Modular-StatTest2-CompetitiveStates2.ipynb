# %%
# %run StatTest2_WithSimulation_Setup.ipynb

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = ["PA", "WI", "OR", "NV", "FL", "VA", "NY", "AZ", "GA", "CO",
          "MI", "ME", "CA", "MO", "OH", "NM", "CT", "MA", "NE", "HI",
          "MN", "AR", "NJ", "MD", "WA", "UT"]
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new = normalize_empirical_data(dfs, states)
# Out:
# 326
# 338
# 302
# 269
# PA 14 Ratio is 1.016
# WI 14 Ratio is 1.037
# OR 14 Ratio is 1.112
# NV 14 Ratio is 1.256
# FL 14 Ratio is 1.104
# VA 14 Ratio is 1.150
# NY 14 Ratio is 0.896
# AZ 14 Ratio is 1.378
# GA 14 Ratio is 1.159
# CO 14 Ratio is 1.107
# MI 14 Ratio is 1.204
# ME 14 Ratio is 1.094
# CA 14 Ratio is 1.062
# MO 14 Ratio is 1.301
# OH 14 Ratio is 1.163
# NM 14 Ratio is 1.051
# CT 14 Ratio is 0.911
# NE 14 Ratio is 1.164
# HI 14 Ratio is 1.081
# MN 14 Ratio is 1.087
# AR 14 Ratio is 1.356
# NJ 14 Ratio is 1.079
# MD 14 Ratio is 1.140
# WA 14 Ratio is 1.103
# UT 14 Ratio is 1.498
# PA 15 Ratio is 0.986
# WI 15 Ratio is 1.011
# OR 15 Ratio is 1.047
# NV 15 Ratio is 1.198
# FL 15 Ratio is 1.069
# VA 15 Ratio is 1.168
# NY 15 Ratio is 0.825
# AZ 15 Ratio is 1.292
# GA 15 Ratio is 1.103
# CO 15 Ratio is 1.091
# MI 15 Ratio is 1.150
# ME 15 Ratio is 1.090
# CA 15 Ratio is 1.028
# MO 15 Ratio is 1.180
# OH 15 Ratio is 1.096
# NM 15 Ratio is 1.019
# CT 15 Ratio is 0.899
# NE 15 Ratio is 1.094
# HI 15 Ratio is 1.000
# MN 15 Ratio is 1.063
# AR 15 Ratio is 1.295
# NJ 15 Ratio is 0.929
# MD 15 Ratio is 1.168
# WA 15 Ratio is 1.064
# UT 15 Ratio is 1.390
# PA 16 Ratio is 0.944
# WI 16 Ratio is 0.969
# OR 16 Ratio is 0.992
# NV 16 Ratio is 1.183
# FL 16 Ratio is 1.023
# VA 16 Ratio is 1.027
# NY 16 Ratio is 0.793
# AZ 16 Ratio is 1.219
# GA 16 Ratio is 1.012
# CO 16 Ratio is 1.082
# MI 16 Ratio is 1.099
# ME 16 Ratio is 1.027
# CA 16 Ratio is 0.968
# MO 16 Ratio is 1.100
# OH 16 Ratio is 1.019
# NM 16 Ratio is 0.893
# CT 16 Ratio is 0.810
# NE 16 Ratio is 1.054
# HI 16 Ratio is 0.961
# MN 16 Ratio is 0.968
# AR 16 Ratio is 1.201
# NJ 16 Ratio is 0.849
# MD 16 Ratio is 1.119
# WA 16 Ratio is 1.044
# UT 16 Ratio is 1.334
# PA 17 Ratio is 0.847
# WI 17 Ratio is 0.925
# OR 17 Ratio is 0.977
# NV 17 Ratio is 1.168
# FL 17 Ratio is 0.963
# VA 17 Ratio is 0.971
# NY 17 Ratio is 0.720
# AZ 17 Ratio is 1.170
# GA 17 Ratio is 0.958
# CO 17 Ratio is 1.012
# MI 17 Ratio is 1.078
# ME 17 Ratio is 0.988
# CA 17 Ratio is 0.934
# MO 17 Ratio is 1.062
# OH 17 Ratio is 0.963
# NM 17 Ratio is 0.869
# CT 17 Ratio is 0.795
# NE 17 Ratio is 1.000
# HI 17 Ratio is 0.899
# MN 17 Ratio is 0.915
# AR 17 Ratio is 1.137
# NJ 17 Ratio is 0.784
# MD 17 Ratio is 1.058
# WA 17 Ratio is 1.026
# UT 17 Ratio is 1.280

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 111300.000

# %%
beta1, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2)
# Out:
# k = 1233
# test_stat at this k = 0.03868
#
# At the point of maximum difference with beta = 111300:
# P(|d_i|<v) = 0.8191
# P(|N(0,max_beta^2)|<v) = 0.2870
# Difference = 0.5322
#
#
#
#
# At the point of maximum difference with beta = 101300:
# P(|d_i|<v) = 0.8013
# P(|N(0,max_beta^2)|<v) = 0.2948
# Difference = 0.5065
#
#
#
#
# At the point of maximum difference with beta = 91300:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.2590
# Difference = 0.4806
#
#
#
#
# At the point of maximum difference with beta = 81300:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.2895
# Difference = 0.4501
#
#
#
#
# At the point of maximum difference with beta = 71300:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.3279
# Difference = 0.4117
#
#
#
#
# At the point of maximum difference with beta = 61300:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.3775
# Difference = 0.3621
#
#
#
#
# At the point of maximum difference with beta = 51300:
# P(|d_i|<v) = 0.7324
# P(|N(0,max_beta^2)|<v) = 0.4360
# Difference = 0.2964
#
#
#
#
# At the point of maximum difference with beta = 41300:
# P(|d_i|<v) = 0.6594
# P(|N(0,max_beta^2)|<v) = 0.4441
# Difference = 0.2152
#
#
#
#
# At the point of maximum difference with beta = 31300:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3243
# Difference = 0.1315
#
#
#
#
# At the point of maximum difference with beta = 31300:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3243
# Difference = 0.1315
#
#
#
#
# At the point of maximum difference with beta = 31200:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3253
# Difference = 0.1305
#
#
#
#
# At the point of maximum difference with beta = 31100:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3263
# Difference = 0.1295
#
#
#
#
# At the point of maximum difference with beta = 31000:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3273
# Difference = 0.1285
#
#
#
#
# At the point of maximum difference with beta = 30900:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3283
# Difference = 0.1275
#
#
#
#
# At the point of maximum difference with beta = 30800:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3293
# Difference = 0.1265
#
#
#
#
# At the point of maximum difference with beta = 30700:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3303
# Difference = 0.1255
#
#
#
#
# At the point of maximum difference with beta = 30600:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3313
# Difference = 0.1245
#
#
#
#
# At the point of maximum difference with beta = 30500:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3323
# Difference = 0.1235
#
#
#
#
# At the point of maximum difference with beta = 30400:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1225
#
#
#
#
# At the point of maximum difference with beta = 30300:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3344
# Difference = 0.1214
#
#
#
#
# At the point of maximum difference with beta = 30200:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3354
# Difference = 0.1204
#
#
#
#
# At the point of maximum difference with beta = 30100:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3365
# Difference = 0.1193
#
#
#
#
# At the point of maximum difference with beta = 30000:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3375
# Difference = 0.1183
#
#
#
#
# At the point of maximum difference with beta = 29900:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3386
# Difference = 0.1172
#
#
#
#
# At the point of maximum difference with beta = 29800:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3396
# Difference = 0.1162
#
#
#
#
# At the point of maximum difference with beta = 29700:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3407
# Difference = 0.1151
#
#
#
#
# At the point of maximum difference with beta = 29600:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3418
# Difference = 0.1140
#
#
#
#
# At the point of maximum difference with beta = 29500:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3429
# Difference = 0.1129
#
#
#
#
# At the point of maximum difference with beta = 29400:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3440
# Difference = 0.1118
#
#
#
#
# At the point of maximum difference with beta = 29300:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3451
# Difference = 0.1107
#
#
#
#
# At the point of maximum difference with beta = 29200:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3462
# Difference = 0.1096
#
#
#
#
# At the point of maximum difference with beta = 29100:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3473
# Difference = 0.1085
#
#
#
#
# At the point of maximum difference with beta = 29000:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3484
# Difference = 0.1074
#
#
#
#
# At the point of maximum difference with beta = 28900:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3495
# Difference = 0.1063
#
#
#
#
# At the point of maximum difference with beta = 28800:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3198
# Difference = 0.1052
#
#
#
#
# At the point of maximum difference with beta = 28700:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3208
# Difference = 0.1041
#
#
#
#
# At the point of maximum difference with beta = 28600:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3219
# Difference = 0.1031
#
#
#
#
# At the point of maximum difference with beta = 28500:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3230
# Difference = 0.1020
#
#
#
#
# At the point of maximum difference with beta = 28400:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3240
# Difference = 0.1009
#
#
#
#
# At the point of maximum difference with beta = 28300:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3251
# Difference = 0.0999
#
#
#
#
# At the point of maximum difference with beta = 28200:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3262
# Difference = 0.0988
#
#
#
#
# At the point of maximum difference with beta = 28100:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3273
# Difference = 0.0977
#
#
#
#
# At the point of maximum difference with beta = 28000:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3284
# Difference = 0.0966
#
#
#
#
# At the point of maximum difference with beta = 27900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.0955
#
#
#
#
# At the point of maximum difference with beta = 27800:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3306
# Difference = 0.0944
#
#
#
#
# At the point of maximum difference with beta = 27700:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3317
# Difference = 0.0932
#
#
#
#
# At the point of maximum difference with beta = 27600:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3329
# Difference = 0.0921
#
#
#
#
# At the point of maximum difference with beta = 27500:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3340
# Difference = 0.0910
#
#
#
#
# At the point of maximum difference with beta = 27400:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3351
# Difference = 0.0898
#
#
#
#
# At the point of maximum difference with beta = 27300:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3363
# Difference = 0.0887
#
#
#
#
# At the point of maximum difference with beta = 27200:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3375
# Difference = 0.0875
#
#
#
#
# At the point of maximum difference with beta = 27100:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3386
# Difference = 0.0864
#
#
#
#
# At the point of maximum difference with beta = 27000:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3398
# Difference = 0.0852
#
#
#
#
# At the point of maximum difference with beta = 26900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3410
# Difference = 0.0840
#
#
#
#
# At the point of maximum difference with beta = 26800:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3000
# Difference = 0.0828
#
#
#
#
# At the point of maximum difference with beta = 26700:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3011
# Difference = 0.0817
#
#
#
#
# At the point of maximum difference with beta = 26600:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3021
# Difference = 0.0807
#
#
#
#
# At the point of maximum difference with beta = 26500:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3032
# Difference = 0.0796
#
#
#
#
# At the point of maximum difference with beta = 26400:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3043
# Difference = 0.0785
#
#
#
#
# At the point of maximum difference with beta = 26300:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3054
# Difference = 0.0774
#
#
#
#
# At the point of maximum difference with beta = 26200:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3065
# Difference = 0.0763
#
#
#
#
# At the point of maximum difference with beta = 26100:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3076
# Difference = 0.0752
#
#
#
#
# At the point of maximum difference with beta = 26000:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3088
# Difference = 0.0740
#
#
#
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3099
# Difference = 0.0729
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3110
# Difference = 0.0718
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.0706
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2638
# Difference = 0.0696
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2648
# Difference = 0.0686
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2658
# Difference = 0.0676
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2668
# Difference = 0.0666
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2678
# Difference = 0.0655
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2688
# Difference = 0.0645
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2699
# Difference = 0.0635
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2709
# Difference = 0.0624
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2719
# Difference = 0.0614
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2730
# Difference = 0.0603
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2741
# Difference = 0.0593
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2751
# Difference = 0.0582
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2762
# Difference = 0.0571
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2773
# Difference = 0.0560
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2784
# Difference = 0.0549
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2795
# Difference = 0.0538
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2806
# Difference = 0.0527
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2818
# Difference = 0.0516
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2829
# Difference = 0.0504
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2003
# Difference = 0.0494
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2012
# Difference = 0.0486
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2020
# Difference = 0.0478
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2029
# Difference = 0.0469
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1736
# Difference = 0.0462
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1743
# Difference = 0.0455
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1751
# Difference = 0.0447
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1758
# Difference = 0.0440
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1766
# Difference = 0.0432
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1773
# Difference = 0.0424
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1781
# Difference = 0.0417
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1789
# Difference = 0.0409
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1797
# Difference = 0.0401
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1805
# Difference = 0.0393

# %%
beta1 = beta1+100

theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 22400
# Number of T/sqrt(n) above 2 stds: 206
# Proportion of T/sqrt(n) above 2 stds: 0.167
# P value = 0.000000

# %%
df3 = create_df3(states, dfs_new)

# %%
ratios_c = create_simulation(states, dfs_new, beta1 - 10000)
ratios_c2 = create_simulation(states, dfs_new, beta1)
ratios_c3 = create_simulation(states, dfs_new, beta1 + 10000)

# %%
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta1 - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta1))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta1 + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (states, len(df2)))
plt.legend()

# %%
beta1, _ = run_test_against_simulation(states, dfs_new, beta1, ratios2)
# Out:
# k = 1233
# test_stat at this k = 0.03868
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.1119
# P(|N(0,max_beta^2)|<v) = 0.0814
# Difference = 0.0305 NOT > test_stat
#
# At the point of maximum difference with beta = 32400:
# P(|d_i|<v) = 0.4396
# P(|N(0,max_beta^2)|<v) = 0.3128
# Difference = 0.1268
#
#
#
#
# At the point of maximum difference with beta = 32300:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1308
#
#
#
#
# At the point of maximum difference with beta = 32200:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.2967
# Difference = 0.1283
#
#
#
#
# At the point of maximum difference with beta = 32100:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3356
# Difference = 0.1202
#
#
#
#
# At the point of maximum difference with beta = 32000:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3270
# Difference = 0.1288
#
#
#
#
# At the point of maximum difference with beta = 31900:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3323
# Difference = 0.1195
#
#
#
#
# At the point of maximum difference with beta = 31800:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3306
# Difference = 0.1211
#
#
#
#
# At the point of maximum difference with beta = 31700:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3334
# Difference = 0.1183
#
#
#
#
# At the point of maximum difference with beta = 31600:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3104
# Difference = 0.1146
#
#
#
#
# At the point of maximum difference with beta = 31500:
# P(|d_i|<v) = 0.4396
# P(|N(0,max_beta^2)|<v) = 0.3198
# Difference = 0.1198
#
#
#
#
# At the point of maximum difference with beta = 31400:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3339
# Difference = 0.1178
#
#
#
#
# At the point of maximum difference with beta = 31300:
# P(|d_i|<v) = 0.4396
# P(|N(0,max_beta^2)|<v) = 0.3203
# Difference = 0.1193
#
#
#
#
# At the point of maximum difference with beta = 31200:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3376
# Difference = 0.1141
#
#
#
#
# At the point of maximum difference with beta = 31100:
# P(|d_i|<v) = 0.4501
# P(|N(0,max_beta^2)|<v) = 0.3388
# Difference = 0.1113
#
#
#
#
# At the point of maximum difference with beta = 31000:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3128
# Difference = 0.1122
#
#
#
#
# At the point of maximum difference with beta = 30900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3141
# Difference = 0.1108
#
#
#
#
# At the point of maximum difference with beta = 30800:
# P(|d_i|<v) = 0.4663
# P(|N(0,max_beta^2)|<v) = 0.3598
# Difference = 0.1066
#
#
#
#
# At the point of maximum difference with beta = 30700:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3388
# Difference = 0.1129
#
#
#
#
# At the point of maximum difference with beta = 30600:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3143
# Difference = 0.1107
#
#
#
#
# At the point of maximum difference with beta = 30500:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3397
# Difference = 0.1121
#
#
#
#
# At the point of maximum difference with beta = 30400:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3178
# Difference = 0.1072
#
#
#
#
# At the point of maximum difference with beta = 30300:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3459
# Difference = 0.1099
#
#
#
#
# At the point of maximum difference with beta = 30200:
# P(|d_i|<v) = 0.4396
# P(|N(0,max_beta^2)|<v) = 0.3337
# Difference = 0.1059
#
#
#
#
# At the point of maximum difference with beta = 30100:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3181
# Difference = 0.1069
#
#
#
#
# At the point of maximum difference with beta = 30000:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3294
# Difference = 0.0956
#
#
#
#
# At the point of maximum difference with beta = 29900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3221
# Difference = 0.1029
#
#
#
#
# At the point of maximum difference with beta = 29800:
# P(|d_i|<v) = 0.4396
# P(|N(0,max_beta^2)|<v) = 0.3399
# Difference = 0.0997
#
#
#
#
# At the point of maximum difference with beta = 29700:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3273
# Difference = 0.0976
#
#
#
#
# At the point of maximum difference with beta = 29600:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3312
# Difference = 0.0938
#
#
#
#
# At the point of maximum difference with beta = 29500:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3301
# Difference = 0.0949
#
#
#
#
# At the point of maximum difference with beta = 29400:
# P(|d_i|<v) = 0.4517
# P(|N(0,max_beta^2)|<v) = 0.3533
# Difference = 0.0985
#
#
#
#
# At the point of maximum difference with beta = 29300:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3276
# Difference = 0.0974
#
#
#
#
# At the point of maximum difference with beta = 29200:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.2906
# Difference = 0.0922
#
#
#
#
# At the point of maximum difference with beta = 29100:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3311
# Difference = 0.0939
#
#
#
#
# At the point of maximum difference with beta = 29000:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.2929
# Difference = 0.0899
#
#
#
#
# At the point of maximum difference with beta = 28900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3323
# Difference = 0.0927
#
#
#
#
# At the point of maximum difference with beta = 28800:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3317
# Difference = 0.0933
#
#
#
#
# At the point of maximum difference with beta = 28700:
# P(|d_i|<v) = 0.3812
# P(|N(0,max_beta^2)|<v) = 0.2973
# Difference = 0.0839
#
#
#
#
# At the point of maximum difference with beta = 28600:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3363
# Difference = 0.0887
#
#
#
#
# At the point of maximum difference with beta = 28500:
# P(|d_i|<v) = 0.3812
# P(|N(0,max_beta^2)|<v) = 0.2983
# Difference = 0.0829
#
#
#
#
# At the point of maximum difference with beta = 28400:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.2963
# Difference = 0.0865
#
#
#
#
# At the point of maximum difference with beta = 28300:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3386
# Difference = 0.0864
#
#
#
#
# At the point of maximum difference with beta = 28200:
# P(|d_i|<v) = 0.4558
# P(|N(0,max_beta^2)|<v) = 0.3753
# Difference = 0.0805
#
#
#
#
# At the point of maximum difference with beta = 28100:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3084
# Difference = 0.0744
#
#
#
#
# At the point of maximum difference with beta = 28000:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3064
# Difference = 0.0764
#
#
#
#
# At the point of maximum difference with beta = 27900:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3089
# Difference = 0.0739
#
#
#
#
# At the point of maximum difference with beta = 27800:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3009
# Difference = 0.0819
#
#
#
#
# At the point of maximum difference with beta = 27700:
# P(|d_i|<v) = 0.3763
# P(|N(0,max_beta^2)|<v) = 0.2979
# Difference = 0.0785
#
#
#
#
# At the point of maximum difference with beta = 27600:
# P(|d_i|<v) = 0.3812
# P(|N(0,max_beta^2)|<v) = 0.3040
# Difference = 0.0772
#
#
#
#
# At the point of maximum difference with beta = 27500:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3034
# Difference = 0.0794
#
#
#
#
# At the point of maximum difference with beta = 27400:
# P(|d_i|<v) = 0.3609
# P(|N(0,max_beta^2)|<v) = 0.2828
# Difference = 0.0781
#
#
#
#
# At the point of maximum difference with beta = 27300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2554
# Difference = 0.0780
#
#
#
#
# At the point of maximum difference with beta = 27200:
# P(|d_i|<v) = 0.3609
# P(|N(0,max_beta^2)|<v) = 0.2920
# Difference = 0.0689
#
#
#
#
# At the point of maximum difference with beta = 27100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2655
# Difference = 0.0679
#
#
#
#
# At the point of maximum difference with beta = 27000:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3129
# Difference = 0.0699
#
#
#
#
# At the point of maximum difference with beta = 26900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2603
# Difference = 0.0730
#
#
#
#
# At the point of maximum difference with beta = 26800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2655
# Difference = 0.0678
#
#
#
#
# At the point of maximum difference with beta = 26700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2636
# Difference = 0.0697
#
#
#
#
# At the point of maximum difference with beta = 26600:
# P(|d_i|<v) = 0.3812
# P(|N(0,max_beta^2)|<v) = 0.3129
# Difference = 0.0683
#
#
#
#
# At the point of maximum difference with beta = 26500:
# P(|d_i|<v) = 0.4396
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.0690
#
#
#
#
# At the point of maximum difference with beta = 26400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2690
# Difference = 0.0643
#
#
#
#
# At the point of maximum difference with beta = 26300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2700
# Difference = 0.0634
# At the point of maximum difference with beta = 26200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2687
# Difference = 0.0646
#
#
#
#
# At the point of maximum difference with beta = 26100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2750
# Difference = 0.0583
#
#
#
#
# At the point of maximum difference with beta = 26000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2726
# Difference = 0.0608
#
#
#
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2682
# Difference = 0.0651
#
#
#
#
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2800
# Difference = 0.0533
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2760
# Difference = 0.0574
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2744
# Difference = 0.0589
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2788
# Difference = 0.0546
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.3609
# P(|N(0,max_beta^2)|<v) = 0.3015
# Difference = 0.0594
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.1997
# Difference = 0.0517
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2854
# Difference = 0.0480
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2829
# Difference = 0.0504
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1670
# Difference = 0.0528
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1719
# Difference = 0.0479
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1725
# Difference = 0.0489
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1969
# Difference = 0.0456
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1932
# Difference = 0.0493
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1699
# Difference = 0.0499
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1715
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1994
# Difference = 0.0431
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1233
# Difference = 0.0389
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1749
# Difference = 0.0449
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2030
# Difference = 0.0468
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1760
# Difference = 0.0438
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1787
# Difference = 0.0411
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1840
# Difference = 0.0357 NOT > test_stat

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 23700
# Number of T/sqrt(n) above 2 stds: 187
# Proportion of T/sqrt(n) above 2 stds: 0.152
# P value = 0.000000
