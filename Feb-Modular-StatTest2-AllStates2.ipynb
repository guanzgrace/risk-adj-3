# %%
# %run StatTest2_WithSimulation_Setup.ipynb

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = list(set(sg_data_14["STATE"]))
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new = normalize_empirical_data(dfs, states)
# Out:
# 539
# 542
# 475
# 414
# IL 14 Ratio is 0.990
# FL 14 Ratio is 1.096
# KY 14 Ratio is 1.270
# KS 14 Ratio is 1.273
# WV 14 Ratio is 0.944
# HI 14 Ratio is 1.074
# MD 14 Ratio is 1.132
# WA 14 Ratio is 1.096
# ND 14 Ratio is 1.099
# AK 14 Ratio is 0.697
# MO 14 Ratio is 1.293
# IN 14 Ratio is 1.153
# NV 14 Ratio is 1.247
# PA 14 Ratio is 1.010
# NC 14 Ratio is 1.146
# NJ 14 Ratio is 1.072
# ID 14 Ratio is 1.357
# ME 14 Ratio is 1.086
# UT 14 Ratio is 1.489
# CO 14 Ratio is 1.100
# DC 14 Ratio is 1.041
# MN 14 Ratio is 1.080
# OR 14 Ratio is 1.104
# VA 14 Ratio is 1.143
# GA 14 Ratio is 1.152
# AZ 14 Ratio is 1.369
# SD 14 Ratio is 1.056
# MT 14 Ratio is 1.083
# MS 14 Ratio is 1.244
# WI 14 Ratio is 1.031
# AL 14 Ratio is 1.056
# AR 14 Ratio is 1.347
# NE 14 Ratio is 1.156
# TX 14 Ratio is 1.082
# NH 14 Ratio is 0.970
# IA 14 Ratio is 1.205
# OH 14 Ratio is 1.155
# MI 14 Ratio is 1.196
# WY 14 Ratio is 0.929
# NM 14 Ratio is 1.044
# CT 14 Ratio is 0.905
# TN 14 Ratio is 1.323
# LA 14 Ratio is 1.083
# NY 14 Ratio is 0.890
# SC 14 Ratio is 1.019
# DE 14 Ratio is 1.054
# OK 14 Ratio is 1.137
# RI 14 Ratio is 0.923
# CA 14 Ratio is 1.055
# IL 15 Ratio is 0.951
# FL 15 Ratio is 1.062
# KY 15 Ratio is 1.187
# KS 15 Ratio is 1.123
# WV 15 Ratio is 0.962
# HI 15 Ratio is 0.993
# MD 15 Ratio is 1.160
# WA 15 Ratio is 1.057
# ND 15 Ratio is 1.002
# AK 15 Ratio is 0.648
# MO 15 Ratio is 1.172
# IN 15 Ratio is 1.076
# NV 15 Ratio is 1.190
# PA 15 Ratio is 0.980
# NC 15 Ratio is 1.079
# NJ 15 Ratio is 0.923
# ID 15 Ratio is 1.310
# ME 15 Ratio is 1.083
# UT 15 Ratio is 1.381
# CO 15 Ratio is 1.084
# DC 15 Ratio is 1.022
# MN 15 Ratio is 1.056
# OR 15 Ratio is 1.040
# VA 15 Ratio is 1.160
# GA 15 Ratio is 1.096
# AZ 15 Ratio is 1.283
# SD 15 Ratio is 1.002
# MT 15 Ratio is 1.006
# MS 15 Ratio is 1.193
# WI 15 Ratio is 1.004
# AL 15 Ratio is 1.003
# AR 15 Ratio is 1.287
# NE 15 Ratio is 1.087
# TX 15 Ratio is 0.993
# NH 15 Ratio is 0.952
# IA 15 Ratio is 1.165
# OH 15 Ratio is 1.089
# MI 15 Ratio is 1.143
# WY 15 Ratio is 0.890
# NM 15 Ratio is 1.013
# CT 15 Ratio is 0.893
# TN 15 Ratio is 1.266
# LA 15 Ratio is 0.987
# NY 15 Ratio is 0.819
# SC 15 Ratio is 0.965
# DE 15 Ratio is 1.112
# OK 15 Ratio is 1.044
# RI 15 Ratio is 0.984
# CA 15 Ratio is 1.021
# IL 16 Ratio is 0.912
# FL 16 Ratio is 1.017
# KY 16 Ratio is 1.094
# KS 16 Ratio is 1.041
# WV 16 Ratio is 0.868
# HI 16 Ratio is 0.955
# MD 16 Ratio is 1.112
# WA 16 Ratio is 1.037
# ND 16 Ratio is 0.968
# AK 16 Ratio is 0.586
# MO 16 Ratio is 1.093
# IN 16 Ratio is 0.987
# NV 16 Ratio is 1.175
# PA 16 Ratio is 0.938
# NC 16 Ratio is 1.076
# NJ 16 Ratio is 0.844
# ID 16 Ratio is 1.203
# ME 16 Ratio is 1.020
# UT 16 Ratio is 1.325
# CO 16 Ratio is 1.075
# DC 16 Ratio is 0.961
# MN 16 Ratio is 0.962
# OR 16 Ratio is 0.986
# VA 16 Ratio is 1.021
# GA 16 Ratio is 1.005
# AZ 16 Ratio is 1.212
# SD 16 Ratio is 0.936
# MT 16 Ratio is 1.049
# MS 16 Ratio is 1.128
# WI 16 Ratio is 0.963
# AL 16 Ratio is 0.978
# AR 16 Ratio is 1.193
# NE 16 Ratio is 1.047
# TX 16 Ratio is 0.917
# NH 16 Ratio is 0.901
# IA 16 Ratio is 1.113
# OH 16 Ratio is 1.012
# MI 16 Ratio is 1.092
# WY 16 Ratio is 0.820
# NM 16 Ratio is 0.888
# CT 16 Ratio is 0.805
# TN 16 Ratio is 1.144
# LA 16 Ratio is 0.971
# NY 16 Ratio is 0.788
# SC 16 Ratio is 0.910
# DE 16 Ratio is 1.001
# OK 16 Ratio is 1.039
# RI 16 Ratio is 0.903
# CA 16 Ratio is 0.961
# IL 17 Ratio is 0.863
# FL 17 Ratio is 0.956
# KY 17 Ratio is 1.015
# KS 17 Ratio is 0.932
# WV 17 Ratio is 0.854
# HI 17 Ratio is 0.893
# MD 17 Ratio is 1.051
# WA 17 Ratio is 1.019
# ND 17 Ratio is 0.965
# AK 17 Ratio is 0.595
# MO 17 Ratio is 1.055
# IN 17 Ratio is 0.945
# NV 17 Ratio is 1.161
# PA 17 Ratio is 0.841
# NC 17 Ratio is 0.937
# NJ 17 Ratio is 0.779
# ID 17 Ratio is 1.169
# ME 17 Ratio is 0.982
# UT 17 Ratio is 1.272
# CO 17 Ratio is 1.006
# DC 17 Ratio is 0.904
# MN 17 Ratio is 0.909
# OR 17 Ratio is 0.970
# VA 17 Ratio is 0.965
# GA 17 Ratio is 0.951
# AZ 17 Ratio is 1.162
# SD 17 Ratio is 0.889
# MT 17 Ratio is 0.988
# MS 17 Ratio is 1.064
# WI 17 Ratio is 0.919
# AL 17 Ratio is 0.973
# AR 17 Ratio is 1.130
# NE 17 Ratio is 0.994
# TX 17 Ratio is 0.892
# NH 17 Ratio is 0.848
# IA 17 Ratio is 1.149
# OH 17 Ratio is 0.957
# MI 17 Ratio is 1.070
# WY 17 Ratio is 0.847
# NM 17 Ratio is 0.864
# CT 17 Ratio is 0.790
# TN 17 Ratio is 1.153
# LA 17 Ratio is 0.943
# NY 17 Ratio is 0.715
# SC 17 Ratio is 0.873
# DE 17 Ratio is 0.871
# OK 17 Ratio is 1.039
# RI 17 Ratio is 0.843
# CA 17 Ratio is 0.928

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 105300.000

# %%
beta1, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2)
# Out:
# k = 1966
# test_stat at this k = 0.03063
#
# At the point of maximum difference with beta = 105300:
# P(|d_i|<v) = 0.7986
# P(|N(0,max_beta^2)|<v) = 0.2242
# Difference = 0.5744
#
#
#
#
# At the point of maximum difference with beta = 95300:
# P(|d_i|<v) = 0.7986
# P(|N(0,max_beta^2)|<v) = 0.2470
# Difference = 0.5516
#
#
#
#
# At the point of maximum difference with beta = 85300:
# P(|d_i|<v) = 0.7986
# P(|N(0,max_beta^2)|<v) = 0.2748
# Difference = 0.5238
#
#
#
#
# At the point of maximum difference with beta = 75300:
# P(|d_i|<v) = 0.7986
# P(|N(0,max_beta^2)|<v) = 0.3095
# Difference = 0.4891
#
#
#
#
# At the point of maximum difference with beta = 65300:
# P(|d_i|<v) = 0.7925
# P(|N(0,max_beta^2)|<v) = 0.3475
# Difference = 0.4450
#
#
#
#
# At the point of maximum difference with beta = 55300:
# P(|d_i|<v) = 0.7269
# P(|N(0,max_beta^2)|<v) = 0.3379
# Difference = 0.3890
#
#
#
#
# At the point of maximum difference with beta = 45300:
# P(|d_i|<v) = 0.7269
# P(|N(0,max_beta^2)|<v) = 0.4063
# Difference = 0.3206
#
#
#
#
# At the point of maximum difference with beta = 35300:
# P(|d_i|<v) = 0.5346
# P(|N(0,max_beta^2)|<v) = 0.2975
# Difference = 0.2370
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3752
# Difference = 0.1304
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3752
# Difference = 0.1304
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3766
# Difference = 0.1290
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3780
# Difference = 0.1276
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3794
# Difference = 0.1262
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3808
# Difference = 0.1248
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3822
# Difference = 0.1234
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3836
# Difference = 0.1220
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3233
# Difference = 0.1207
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3246
# Difference = 0.1195
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3258
# Difference = 0.1182
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3271
# Difference = 0.1169
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3284
# Difference = 0.1157
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3297
# Difference = 0.1144
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3310
# Difference = 0.1131
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3323
# Difference = 0.1118
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3336
# Difference = 0.1105
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3349
# Difference = 0.1092
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3362
# Difference = 0.1078
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3376
# Difference = 0.1065
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3389
# Difference = 0.1051
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3403
# Difference = 0.1038
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1024
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3180
# Difference = 0.1011
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3193
# Difference = 0.0998
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3207
# Difference = 0.0985
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3220
# Difference = 0.0971
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3233
# Difference = 0.0958
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3247
# Difference = 0.0945
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3260
# Difference = 0.0931
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3274
# Difference = 0.0917
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.0903
#
#
#
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3302
# Difference = 0.0889
#
#
#
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3316
# Difference = 0.0875
#
#
#
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3330
# Difference = 0.0861
#
#
#
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3344
# Difference = 0.0847
#
#
#
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2085
# Difference = 0.0834
#
#
#
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2095
# Difference = 0.0825
#
#
#
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2104
# Difference = 0.0815
#
#
#
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2114
# Difference = 0.0806
#
#
#
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2123
# Difference = 0.0796
#
#
#
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2133
# Difference = 0.0786
#
#
#
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2143
# Difference = 0.0777
#
#
#
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2153
# Difference = 0.0767
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2163
# Difference = 0.0757
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1939
# Difference = 0.0747
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1948
# Difference = 0.0738
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1957
# Difference = 0.0729
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1966
# Difference = 0.0719
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1976
# Difference = 0.0710
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1985
# Difference = 0.0700
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1995
# Difference = 0.0691
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2005
# Difference = 0.0681
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2014
# Difference = 0.0671
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2024
# Difference = 0.0661
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2034
# Difference = 0.0652
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2044
# Difference = 0.0641
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2054
# Difference = 0.0631
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2065
# Difference = 0.0621
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2075
# Difference = 0.0611
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2085
# Difference = 0.0600
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2096
# Difference = 0.0590
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2107
# Difference = 0.0579
#
#
#
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2117
# Difference = 0.0568
#
#
#
#
# At the point of maximum difference with beta = 19000:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2128
# Difference = 0.0557
#
#
#
#
# At the point of maximum difference with beta = 18900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2139
# Difference = 0.0546
#
#
#
#
# At the point of maximum difference with beta = 18800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2150
# Difference = 0.0535
#
#
#
#
# At the point of maximum difference with beta = 18700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2162
# Difference = 0.0524
#
#
#
#
# At the point of maximum difference with beta = 18600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2173
# Difference = 0.0513
#
#
#
#
# At the point of maximum difference with beta = 18500:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2184
# Difference = 0.0501
#
#
#
#
# At the point of maximum difference with beta = 18400:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2196
# Difference = 0.0490
#
#
#
#
# At the point of maximum difference with beta = 18300:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2208
# Difference = 0.0478
#
#
#
#
# At the point of maximum difference with beta = 18200:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2219
# Difference = 0.0466
#
#
#
#
# At the point of maximum difference with beta = 18100:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2231
# Difference = 0.0454
#
#
#
#
# At the point of maximum difference with beta = 18000:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2243
# Difference = 0.0442
#
#
#
#
# At the point of maximum difference with beta = 17900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2256
# Difference = 0.0430
#
#
#
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2268
# Difference = 0.0418
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2280
# Difference = 0.0405
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2293
# Difference = 0.0393
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0962
# Difference = 0.0386
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0968
# Difference = 0.0380
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0973
# Difference = 0.0375
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0979
# Difference = 0.0369
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0984
# Difference = 0.0363
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0990
# Difference = 0.0358
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0996
# Difference = 0.0352
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1002
# Difference = 0.0346
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1008
# Difference = 0.0340
#
#
#
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1014
# Difference = 0.0334
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1020
# Difference = 0.0328
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1026
# Difference = 0.0322
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1033
# Difference = 0.0315
#
#
#
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1039
# Difference = 0.0309

# %%
beta1 = beta1+100

theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 16200
# Number of T/sqrt(n) above 2 stds: 370
# Proportion of T/sqrt(n) above 2 stds: 0.188
# P value = 0.000000

# %%
df3 = create_df3(states, dfs_new)

# %%
ratios_c = create_simulation(states, dfs_new, beta1 - 10000)
ratios_c2 = create_simulation(states, dfs_new, beta1)
ratios_c3 = create_simulation(states, dfs_new, beta1 + 10000)

# %%
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta1 - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta1))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta1 + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (states, len(df2)))
plt.legend()

# %%
beta1, _ = run_test_against_simulation(states, dfs_new, beta1, ratios2)
# Out:
# k = 1966
# test_stat at this k = 0.03063
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.0839
# P(|N(0,max_beta^2)|<v) = 0.0613
# Difference = 0.0226 NOT > test_stat
#
# At the point of maximum difference with beta = 26200:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1145
#
#
#
#
# At the point of maximum difference with beta = 26100:
# P(|d_i|<v) = 0.4471
# P(|N(0,max_beta^2)|<v) = 0.3329
# Difference = 0.1142
#
#
#
#
# At the point of maximum difference with beta = 26000:
# P(|d_i|<v) = 0.5056
# P(|N(0,max_beta^2)|<v) = 0.3908
# Difference = 0.1148
#
#
#
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3334
# Difference = 0.1106
#
#
#
#
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.4390
# P(|N(0,max_beta^2)|<v) = 0.3236
# Difference = 0.1154
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3030
# Difference = 0.1162
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3349
# Difference = 0.1092
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3144
# Difference = 0.1063
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3368
# Difference = 0.1072
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3146
# Difference = 0.1045
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3384
# Difference = 0.1056
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.4471
# P(|N(0,max_beta^2)|<v) = 0.3410
# Difference = 0.1061
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.4471
# P(|N(0,max_beta^2)|<v) = 0.3449
# Difference = 0.1022
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3220
# Difference = 0.0986
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3427
# Difference = 0.1013
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.4390
# P(|N(0,max_beta^2)|<v) = 0.3392
# Difference = 0.0998
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3516
# Difference = 0.0924
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3281
# Difference = 0.0925
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3221
# Difference = 0.0970
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3302
# Difference = 0.0889
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3511
# Difference = 0.0930
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3290
# Difference = 0.0916
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.4440
# P(|N(0,max_beta^2)|<v) = 0.3555
# Difference = 0.0885
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3047
# P(|N(0,max_beta^2)|<v) = 0.2158
# Difference = 0.0888
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3343
# Difference = 0.0848
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.4191
# P(|N(0,max_beta^2)|<v) = 0.3350
# Difference = 0.0842
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2991
# P(|N(0,max_beta^2)|<v) = 0.2170
# Difference = 0.0821
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3370
# Difference = 0.0837
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3403
# Difference = 0.0804
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2127
# Difference = 0.0792
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.4222
# P(|N(0,max_beta^2)|<v) = 0.3398
# Difference = 0.0823
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.4207
# P(|N(0,max_beta^2)|<v) = 0.3412
# Difference = 0.0795
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.4222
# P(|N(0,max_beta^2)|<v) = 0.3427
# Difference = 0.0795
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2144
# Difference = 0.0776
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2782
# P(|N(0,max_beta^2)|<v) = 0.2030
# Difference = 0.0752
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1958
# Difference = 0.0728
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2179
# Difference = 0.0741
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2178
# Difference = 0.0742
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2782
# P(|N(0,max_beta^2)|<v) = 0.2006
# Difference = 0.0776
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.3047
# P(|N(0,max_beta^2)|<v) = 0.2359
# Difference = 0.0687
#
#
#
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2205
# Difference = 0.0714
#
#
#
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1950
# Difference = 0.0736
#
#
#
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1994
# Difference = 0.0692
#
#
#
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2012
# Difference = 0.0674
#
#
#
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.1999
# Difference = 0.0686
#
#
#
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.2920
# P(|N(0,max_beta^2)|<v) = 0.2235
# Difference = 0.0685
#
#
#
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.2991
# P(|N(0,max_beta^2)|<v) = 0.2338
# Difference = 0.0653
#
#
#
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.2782
# P(|N(0,max_beta^2)|<v) = 0.2146
# Difference = 0.0636
#
#
#
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2079
# Difference = 0.0607
#
#
#
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.2782
# P(|N(0,max_beta^2)|<v) = 0.2158
# Difference = 0.0625
#
#
#
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2104
# Difference = 0.0582
#
#
#
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2076
# Difference = 0.0610
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2111
# Difference = 0.0575
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2104
# Difference = 0.0581
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2107
# Difference = 0.0579
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2160
# Difference = 0.0525
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2157
# Difference = 0.0529
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2161
# Difference = 0.0525
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.2660
# P(|N(0,max_beta^2)|<v) = 0.2138
# Difference = 0.0523
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2159
# Difference = 0.0526
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2175
# Difference = 0.0511
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2220
# Difference = 0.0466
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.2660
# P(|N(0,max_beta^2)|<v) = 0.2178
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2229
# Difference = 0.0457
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2202
# Difference = 0.0484
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2197
# Difference = 0.0489
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2263
# Difference = 0.0423
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2270
# Difference = 0.0416
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0922
# Difference = 0.0426
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2276
# Difference = 0.0410
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.2660
# P(|N(0,max_beta^2)|<v) = 0.2235
# Difference = 0.0426
#
#
#
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.2660
# P(|N(0,max_beta^2)|<v) = 0.2271
# Difference = 0.0390
#
#
#
#
# At the point of maximum difference with beta = 19000:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0974
# Difference = 0.0374
#
#
#
#
# At the point of maximum difference with beta = 18900:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1031
# Difference = 0.0317
#
#
#
#
# At the point of maximum difference with beta = 18800:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0951
# Difference = 0.0397
#
#
#
#
# At the point of maximum difference with beta = 18700:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0996
# Difference = 0.0352
#
#
#
#
# At the point of maximum difference with beta = 18600:
# P(|d_i|<v) = 0.2686
# P(|N(0,max_beta^2)|<v) = 0.2312
# Difference = 0.0374
#
#
#
#
# At the point of maximum difference with beta = 18500:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1003
# Difference = 0.0345
#
#
#
#
# At the point of maximum difference with beta = 18400:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0996
# Difference = 0.0352
#
#
#
#
# At the point of maximum difference with beta = 18300:
# P(|d_i|<v) = 0.1089
# P(|N(0,max_beta^2)|<v) = 0.0778
# Difference = 0.0310
#
#
#
#
# At the point of maximum difference with beta = 18200:
# P(|d_i|<v) = 0.1089
# P(|N(0,max_beta^2)|<v) = 0.0757
# Difference = 0.0332
#
#
#
#
# At the point of maximum difference with beta = 18100:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.0975
# Difference = 0.0373
#
#
#
#
# At the point of maximum difference with beta = 18000:
# P(|d_i|<v) = 0.1089
# P(|N(0,max_beta^2)|<v) = 0.0738
# Difference = 0.0351
#
#
#
#
# At the point of maximum difference with beta = 17900:
# P(|d_i|<v) = 0.1348
# P(|N(0,max_beta^2)|<v) = 0.1028
# Difference = 0.0320
#
#
#
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.0900
# P(|N(0,max_beta^2)|<v) = 0.0600
# Difference = 0.0301 NOT > test_stat

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Beta (=std): 17800
# Number of T/sqrt(n) above 2 stds: 325
# Proportion of T/sqrt(n) above 2 stds: 0.165
# P value = 0.000000
