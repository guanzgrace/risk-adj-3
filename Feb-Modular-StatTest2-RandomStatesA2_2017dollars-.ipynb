# %%
# %run StatTest2_WithSimulation_Setup.ipynb
# Out:
# {0: ['ME', 'IL', 'PA', 'GA', 'OK', 'DE', 'WA', 'CT', 'OH', 'VA', 'NE', 'MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'SC', 'RI', 'AK', 'KY', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 1: ['SD', 'IL', 'PA', 'NH', 'NM', 'NV', 'OK', 'UT', 'CT', 'OH', 'VA', 'OR', 'CO', 'IN', 'HI', 'AL', 'RI', 'AK', 'LA', 'MN', 'IA', 'AR', 'WV'], 2: ['MI', 'ME', 'WY', 'DC', 'TX', 'AZ', 'NC', 'WA', 'OR', 'CO', 'MT', 'ND', 'TN', 'SC', 'AL', 'NY', 'KY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 3: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'GA', 'AZ', 'NM', 'NC', 'NV', 'DE', 'UT', 'NE', 'CA', 'MD', 'TN', 'NY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO']}
# {0: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'AZ', 'NM', 'NC', 'NV', 'UT', 'OR', 'CO', 'TN', 'AL', 'NY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 1: ['MI', 'ME', 'WY', 'DC', 'TX', 'GA', 'AZ', 'NC', 'DE', 'WA', 'NE', 'MT', 'CA', 'ND', 'MD', 'TN', 'SC', 'NY', 'KY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO'], 2: ['SD', 'IL', 'PA', 'NH', 'GA', 'NM', 'NV', 'OK', 'DE', 'UT', 'CT', 'OH', 'VA', 'NE', 'IN', 'CA', 'HI', 'MD', 'RI', 'AK', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 3: ['ME', 'IL', 'PA', 'OK', 'WA', 'CT', 'OH', 'VA', 'OR', 'CO', 'MT', 'IN', 'HI', 'ND', 'SC', 'AL', 'RI', 'AK', 'KY', 'LA', 'MN', 'IA', 'AR', 'WV']}

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = list(set(sg_data_14["STATE"]))
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

print_label = "Random States A"

# %%
dfs_new = normalize_empirical_data_split_randomly_for_years(dfs)
# Out:
# ME 14 Ratio is 1.188
# IL 14 Ratio is 1.083
# PA 14 Ratio is 1.105
# GA 14 Ratio is 1.260
# OK 14 Ratio is 1.244
# DE 14 Ratio is 1.153
# WA 14 Ratio is 1.199
# CT 14 Ratio is 0.990
# OH 14 Ratio is 1.264
# VA 14 Ratio is 1.250
# NE 14 Ratio is 1.265
# MT 14 Ratio is 1.184
# IN 14 Ratio is 1.261
# CA 14 Ratio is 1.154
# HI 14 Ratio is 1.175
# ND 14 Ratio is 1.202
# MD 14 Ratio is 1.238
# SC 14 Ratio is 1.115
# RI 14 Ratio is 1.009
# AK 14 Ratio is 0.763
# KY 14 Ratio is 1.389
# WI 14 Ratio is 1.127
# LA 14 Ratio is 1.184
# MN 14 Ratio is 1.182
# MS 14 Ratio is 1.361
# WV 14 Ratio is 1.032
# FL 14 Ratio is 1.199
# SD 15 Ratio is 1.096
# IL 15 Ratio is 1.040
# PA 15 Ratio is 1.072
# NH 15 Ratio is 1.041
# NM 15 Ratio is 1.108
# NV 15 Ratio is 1.302
# OK 15 Ratio is 1.142
# UT 15 Ratio is 1.511
# CT 15 Ratio is 0.977
# OH 15 Ratio is 1.191
# VA 15 Ratio is 1.269
# OR 15 Ratio is 1.138
# CO 15 Ratio is 1.185
# IN 15 Ratio is 1.177
# HI 15 Ratio is 1.086
# AL 15 Ratio is 1.097
# RI 15 Ratio is 1.077
# AK 15 Ratio is 0.709
# LA 15 Ratio is 1.080
# MN 15 Ratio is 1.156
# IA 15 Ratio is 1.274
# AR 15 Ratio is 1.407
# WV 15 Ratio is 1.052
# MI 16 Ratio is 1.195
# ME 16 Ratio is 1.116
# WY 16 Ratio is 0.897
# DC 16 Ratio is 1.051
# TX 16 Ratio is 1.003
# AZ 16 Ratio is 1.325
# NC 16 Ratio is 1.177
# WA 16 Ratio is 1.134
# OR 16 Ratio is 1.078
# CO 16 Ratio is 1.176
# MT 16 Ratio is 1.148
# ND 16 Ratio is 1.058
# TN 16 Ratio is 1.252
# SC 16 Ratio is 0.995
# AL 16 Ratio is 1.070
# NY 16 Ratio is 0.862
# KY 16 Ratio is 1.197
# NJ 16 Ratio is 0.923
# KS 16 Ratio is 1.138
# ID 16 Ratio is 1.316
# IA 16 Ratio is 1.217
# AR 16 Ratio is 1.305
# MO 16 Ratio is 1.195
# MI 17 Ratio is 1.171
# SD 17 Ratio is 0.972
# WY 17 Ratio is 0.926
# NH 17 Ratio is 0.928
# DC 17 Ratio is 0.989
# TX 17 Ratio is 0.976
# GA 17 Ratio is 1.041
# AZ 17 Ratio is 1.271
# NM 17 Ratio is 0.945
# NC 17 Ratio is 1.025
# NV 17 Ratio is 1.270
# DE 17 Ratio is 0.953
# UT 17 Ratio is 1.391
# NE 17 Ratio is 1.087
# CA 17 Ratio is 1.015
# MD 17 Ratio is 1.150
# TN 17 Ratio is 1.261
# NY 17 Ratio is 0.782
# NJ 17 Ratio is 0.852
# KS 17 Ratio is 1.019
# WI 17 Ratio is 1.005
# ID 17 Ratio is 1.279
# MS 17 Ratio is 1.164
# FL 17 Ratio is 1.046
# MO 17 Ratio is 1.154
# Empirical Transfers Sum = 4004561593.220

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
#dfs_new[3][["TransfersPerSqrtEnrollee", "TransfersNormalizedPerSqrtEnrollee"]]

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (print_label, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 115700.000

# %%
beta_theoretical, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2, False)
# Out:
# k = 976
# test_stat at this k = 0.03900
#
# At the point of maximum difference with beta = 115700:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2232
# Difference = 0.5873
#
#
#
#
# At the point of maximum difference with beta = 105700:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2436
# Difference = 0.5668
#
#
#
#
# At the point of maximum difference with beta = 95700:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2682
# Difference = 0.5423
#
#
#
#
# At the point of maximum difference with beta = 85700:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.2980
# Difference = 0.5124
#
#
#
#
# At the point of maximum difference with beta = 75700:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.3351
# Difference = 0.4753
#
#
#
#
# At the point of maximum difference with beta = 65700:
# P(|d_i|<v) = 0.8105
# P(|N(0,max_beta^2)|<v) = 0.3823
# Difference = 0.4281
#
#
#
#
# At the point of maximum difference with beta = 55700:
# P(|d_i|<v) = 0.6926
# P(|N(0,max_beta^2)|<v) = 0.3207
# Difference = 0.3719
#
#
#
#
# At the point of maximum difference with beta = 45700:
# P(|d_i|<v) = 0.6373
# P(|N(0,max_beta^2)|<v) = 0.3240
# Difference = 0.3133
#
#
#
#
# At the point of maximum difference with beta = 35700:
# P(|d_i|<v) = 0.5338
# P(|N(0,max_beta^2)|<v) = 0.2971
# Difference = 0.2367
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4016
# Difference = 0.1301
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4016
# Difference = 0.1301
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4031
# Difference = 0.1287
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4045
# Difference = 0.1273
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4059
# Difference = 0.1258
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4074
# Difference = 0.1244
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4089
# Difference = 0.1229
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4103
# Difference = 0.1214
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4118
# Difference = 0.1199
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4133
# Difference = 0.1184
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4148
# Difference = 0.1169
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4164
# Difference = 0.1154
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4179
# Difference = 0.1139
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4194
# Difference = 0.1123
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4210
# Difference = 0.1108
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4225
# Difference = 0.1092
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4241
# Difference = 0.1077
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4257
# Difference = 0.1061
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4273
# Difference = 0.1045
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4289
# Difference = 0.1029
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4305
# Difference = 0.1013
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4321
# Difference = 0.0996
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4338
# Difference = 0.0980
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4354
# Difference = 0.0963
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4371
# Difference = 0.0947
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4388
# Difference = 0.0930
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4404
# Difference = 0.0913
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4421
# Difference = 0.0896
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.5318
# P(|N(0,max_beta^2)|<v) = 0.4439
# Difference = 0.0879
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2155
# Difference = 0.0867
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2164
# Difference = 0.0858
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2174
# Difference = 0.0849
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2183
# Difference = 0.0839
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2193
# Difference = 0.0830
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2202
# Difference = 0.0820
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2212
# Difference = 0.0811
#
#
#
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2221
# Difference = 0.0801
#
#
#
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2231
# Difference = 0.0791
#
#
#
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.3023
# P(|N(0,max_beta^2)|<v) = 0.2241
# Difference = 0.0781
#
#
#
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2005
# Difference = 0.0772
#
#
#
#
# At the point of maximum difference with beta = 21800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2014
# Difference = 0.0763
#
#
#
#
# At the point of maximum difference with beta = 21700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2023
# Difference = 0.0753
#
#
#
#
# At the point of maximum difference with beta = 21600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2032
# Difference = 0.0744
#
#
#
#
# At the point of maximum difference with beta = 21500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2042
# Difference = 0.0735
#
#
#
#
# At the point of maximum difference with beta = 21400:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2051
# Difference = 0.0726
#
#
#
#
# At the point of maximum difference with beta = 21300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2060
# Difference = 0.0716
#
#
#
#
# At the point of maximum difference with beta = 21200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2070
# Difference = 0.0707
#
#
#
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2079
# Difference = 0.0697
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2089
# Difference = 0.0688
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2099
# Difference = 0.0678
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2109
# Difference = 0.0668
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2119
# Difference = 0.0658
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2129
# Difference = 0.0648
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2139
# Difference = 0.0638
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2149
# Difference = 0.0628
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2159
# Difference = 0.0617
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2170
# Difference = 0.0607
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2180
# Difference = 0.0596
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2191
# Difference = 0.0586
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2202
# Difference = 0.0575
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2212
# Difference = 0.0564
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2223
# Difference = 0.0553
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2234
# Difference = 0.0542
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2246
# Difference = 0.0531
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2257
# Difference = 0.0520
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2268
# Difference = 0.0508
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2280
# Difference = 0.0497
#
#
#
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2291
# Difference = 0.0485
#
#
#
#
# At the point of maximum difference with beta = 19000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0734
# Difference = 0.0475
#
#
#
#
# At the point of maximum difference with beta = 18900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0738
# Difference = 0.0471
#
#
#
#
# At the point of maximum difference with beta = 18800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0742
# Difference = 0.0467
#
#
#
#
# At the point of maximum difference with beta = 18700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0746
# Difference = 0.0463
#
#
#
#
# At the point of maximum difference with beta = 18600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0750
# Difference = 0.0459
#
#
#
#
# At the point of maximum difference with beta = 18500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0754
# Difference = 0.0455
#
#
#
#
# At the point of maximum difference with beta = 18400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0758
# Difference = 0.0451
#
#
#
#
# At the point of maximum difference with beta = 18300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0762
# Difference = 0.0447
#
#
#
#
# At the point of maximum difference with beta = 18200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0766
# Difference = 0.0443
#
#
#
#
# At the point of maximum difference with beta = 18100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0770
# Difference = 0.0439
#
#
#
#
# At the point of maximum difference with beta = 18000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0775
# Difference = 0.0434
#
#
#
#
# At the point of maximum difference with beta = 17900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0779
# Difference = 0.0430
#
#
#
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0783
# Difference = 0.0426
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0788
# Difference = 0.0421
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0792
# Difference = 0.0417
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0797
# Difference = 0.0412
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0801
# Difference = 0.0408
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0806
# Difference = 0.0403
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0811
# Difference = 0.0398
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0815
# Difference = 0.0394

# %%
beta_theoretical = beta_theoretical+100

theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (print_label, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 17100
# Number of T/sqrt(n) above 2 stds: 178
# Proportion of T/sqrt(n) above 2 stds: 0.182
# P value = 0.000000

# %%
ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical - 10000)
ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical)
ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical + 10000)
# Out:
# Sum sqrt(a) = 102167.338
# Sum sqrt(a) = 102167.338
# Sum sqrt(a) = 102167.338

# %%
theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta_theoretical - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta_theoretical))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta_theoretical + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (print_label, len(df2)))
plt.legend()

# %%
beta_sims = list()

for i in range(5):
    beta_sim, _= run_test_against_simulation(states, dfs_new, beta_theoretical, ratios2, False)
    beta_sims.append(beta_sim)
# Out:
# k = 976
# test_stat at this k = 0.03900
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0720
# Difference = 0.0489
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2225
# Difference = 0.0551
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2261
# Difference = 0.0516
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2299
# Difference = 0.0477
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2245
# Difference = 0.0532
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.2756
# P(|N(0,max_beta^2)|<v) = 0.2199
# Difference = 0.0557
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0697
# Difference = 0.0512
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0749
# Difference = 0.0460
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0958
# Difference = 0.0426
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2339
# Difference = 0.0437
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2293
# Difference = 0.0484
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0740
# Difference = 0.0469
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0773
# Difference = 0.0436
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0763
# Difference = 0.0446
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0758
# Difference = 0.0452
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0769
# Difference = 0.0440
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0827
# Difference = 0.0382 NOT > test_stat
# k = 976
# test_stat at this k = 0.03900
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2274
# Difference = 0.0503
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0726
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2241
# Difference = 0.0536
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2260
# Difference = 0.0516
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0889
# Difference = 0.0494
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2293
# Difference = 0.0484
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0747
# Difference = 0.0462
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0752
# Difference = 0.0457
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0764
# Difference = 0.0445
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0798
# Difference = 0.0411
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0742
# Difference = 0.0467
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0984
# Difference = 0.0400
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0788
# Difference = 0.0421
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0790
# Difference = 0.0419
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0739
# Difference = 0.0470
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0770
# Difference = 0.0439
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0787
# Difference = 0.0422
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0778
# Difference = 0.0431
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0800
# Difference = 0.0409
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0799
# Difference = 0.0410
#
#
#
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0796
# Difference = 0.0413
#
#
#
#
# At the point of maximum difference with beta = 19000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0806
# Difference = 0.0403
#
#
#
#
# At the point of maximum difference with beta = 18900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0807
# Difference = 0.0402
#
#
#
#
# At the point of maximum difference with beta = 18800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0822
# Difference = 0.0387 NOT > test_stat
# k = 976
# test_stat at this k = 0.03900
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2247
# Difference = 0.0529
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2271
# Difference = 0.0505
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2756
# P(|N(0,max_beta^2)|<v) = 0.2211
# Difference = 0.0545
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0761
# Difference = 0.0448
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2315
# Difference = 0.0462
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0737
# Difference = 0.0472
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0764
# Difference = 0.0445
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0767
# Difference = 0.0442
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0750
# Difference = 0.0459
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0954
# Difference = 0.0430
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0747
# Difference = 0.0462
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0772
# Difference = 0.0437
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0730
# Difference = 0.0479
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0751
# Difference = 0.0458
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0777
# Difference = 0.0432
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0789
# Difference = 0.0420
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0793
# Difference = 0.0416
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0784
# Difference = 0.0425
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0822
# Difference = 0.0387 NOT > test_stat
# k = 976
# test_stat at this k = 0.03900
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2299
# Difference = 0.0477
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2756
# P(|N(0,max_beta^2)|<v) = 0.2258
# Difference = 0.0498
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2294
# Difference = 0.0482
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0719
# Difference = 0.0490
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2301
# Difference = 0.0475
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0773
# Difference = 0.0436
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0732
# Difference = 0.0477
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0788
# Difference = 0.0421
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0748
# Difference = 0.0461
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2307
# Difference = 0.0469
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0753
# Difference = 0.0456
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0764
# Difference = 0.0445
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0784
# Difference = 0.0425
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.1773
# P(|N(0,max_beta^2)|<v) = 0.1342
# Difference = 0.0430
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0760
# Difference = 0.0449
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0787
# Difference = 0.0422
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0786
# Difference = 0.0423
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0760
# Difference = 0.0449
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0746
# Difference = 0.0463
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0826
# Difference = 0.0383 NOT > test_stat
# k = 976
# test_stat at this k = 0.03900
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2260
# Difference = 0.0517
#
#
#
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2204
# Difference = 0.0572
#
#
#
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2293
# Difference = 0.0484
#
#
#
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2320
# Difference = 0.0457
#
#
#
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0767
# Difference = 0.0442
#
#
#
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.2777
# P(|N(0,max_beta^2)|<v) = 0.2332
# Difference = 0.0445
#
#
#
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0926
# Difference = 0.0458
#
#
#
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0768
# Difference = 0.0441
#
#
#
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0739
# Difference = 0.0470
#
#
#
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0792
# Difference = 0.0417
#
#
#
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0807
# Difference = 0.0402
#
#
#
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0781
# Difference = 0.0428
#
#
#
#
# At the point of maximum difference with beta = 19900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0745
# Difference = 0.0464
#
#
#
#
# At the point of maximum difference with beta = 19800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0762
# Difference = 0.0447
#
#
#
#
# At the point of maximum difference with beta = 19700:
# P(|d_i|<v) = 0.1393
# P(|N(0,max_beta^2)|<v) = 0.0939
# Difference = 0.0454
#
#
#
#
# At the point of maximum difference with beta = 19600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0760
# Difference = 0.0449
#
#
#
#
# At the point of maximum difference with beta = 19500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0801
# Difference = 0.0408
#
#
#
#
# At the point of maximum difference with beta = 19400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0778
# Difference = 0.0431
#
#
#
#
# At the point of maximum difference with beta = 19300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0764
# Difference = 0.0445
#
#
#
#
# At the point of maximum difference with beta = 19200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0806
# Difference = 0.0403
#
#
#
#
# At the point of maximum difference with beta = 19100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0820
# Difference = 0.0389 NOT > test_stat

# %%
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
# Out:
# Simulation without Adjustment Test Results
# Beta (=std): 19180
# Number of T/sqrt(n) above 2 stds: 156
# Proportion of T/sqrt(n) above 2 stds: 0.160
# P value = 0.000000
# Beta (=std): 19180
# Number of T/sqrt(n) above 3 stds: 91
# Proportion of T/sqrt(n) above 3 stds: 0.093
# P value = 0.000000

# %%
beta_sim_adjs = list()

for i in range(5):
    beta_sim_adj, _= run_test_against_simulation_adjust_for_imbalances(states, dfs_new,
                                                                   beta_theoretical, ratios2, False)
    beta_sim_adjs.append(beta_sim_adj)
# Out:
# k = 976
# test_stat at this k = 0.03900
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0769
# Difference = 0.0440
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0750
# Difference = 0.0459
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0747
# Difference = 0.0462
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0809
# Difference = 0.0400
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0763
# Difference = 0.0446
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0796
# Difference = 0.0413
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0788
# Difference = 0.0421
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0794
# Difference = 0.0415
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0758
# Difference = 0.0451
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0775
# Difference = 0.0434
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0786
# Difference = 0.0423
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0822
# Difference = 0.0387 NOT > test_stat
# E(|X|) = 1630354833.962
# k = 976
# test_stat at this k = 0.03900
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0794
# Difference = 0.0415
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0781
# Difference = 0.0428
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0776
# Difference = 0.0433
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0765
# Difference = 0.0444
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0790
# Difference = 0.0419
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0770
# Difference = 0.0439
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0763
# Difference = 0.0446
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0779
# Difference = 0.0430
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0790
# Difference = 0.0419
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.0973
# P(|N(0,max_beta^2)|<v) = 0.0615
# Difference = 0.0358 NOT > test_stat
# E(|X|) = 1646658382.301
# k = 976
# test_stat at this k = 0.03900
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0794
# Difference = 0.0415
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0781
# Difference = 0.0428
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0798
# Difference = 0.0411
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0961
# Difference = 0.0422
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0776
# Difference = 0.0433
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0797
# Difference = 0.0412
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0815
# Difference = 0.0394
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.1007
# Difference = 0.0376 NOT > test_stat
# E(|X|) = 1662961930.641
# k = 976
# test_stat at this k = 0.03900
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0942
# Difference = 0.0441
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0774
# Difference = 0.0435
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0962
# Difference = 0.0421
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0745
# Difference = 0.0464
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0760
# Difference = 0.0449
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0971
# Difference = 0.0413
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20500:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0783
# Difference = 0.0426
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20400:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0784
# Difference = 0.0425
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20300:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0801
# Difference = 0.0408
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20200:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0783
# Difference = 0.0426
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0762
# Difference = 0.0447
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20000:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0847
# Difference = 0.0362 NOT > test_stat
# E(|X|) = 1630354833.962
# k = 976
# test_stat at this k = 0.03900
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21100:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0742
# Difference = 0.0467
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 21000:
# P(|d_i|<v) = 0.1383
# P(|N(0,max_beta^2)|<v) = 0.0916
# Difference = 0.0467
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20900:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0764
# Difference = 0.0445
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20800:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0745
# Difference = 0.0464
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20700:
# P(|d_i|<v) = 0.1209
# P(|N(0,max_beta^2)|<v) = 0.0787
# Difference = 0.0422
#
#
#
# Sum sqrt(a) = 102167.338
#
# At the point of maximum difference with beta = 20600:
# P(|d_i|<v) = 0.0973
# P(|N(0,max_beta^2)|<v) = 0.0594
# Difference = 0.0380 NOT > test_stat
# E(|X|) = 1679265478.980

# %%
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Simulation WITH Adjustment Test Results
# Beta (=std): 20240
# Number of T/sqrt(n) above 2 stds: 148
# Proportion of T/sqrt(n) above 2 stds: 0.152
# P value = 0.000000
# Beta (=std): 20240
# Number of T/sqrt(n) above 3 stds: 84
# Proportion of T/sqrt(n) above 3 stds: 0.086
# P value = 0.000000

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
run_binom_stat_test3(beta_theoretical, df2.values)
print("\n")
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
print("\n")
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 17100
# Number of T/sqrt(n) above 2 stds: 178
# Proportion of T/sqrt(n) above 2 stds: 0.182
# P value = 0.000000
# Beta (=std): 17100
# Number of T/sqrt(n) above 3 stds: 113
# Proportion of T/sqrt(n) above 3 stds: 0.116
# P value = 0.000000
#
#
# Simulation without Adjustment Test Results
# Beta (=std): 19180
# Number of T/sqrt(n) above 2 stds: 156
# Proportion of T/sqrt(n) above 2 stds: 0.160
# P value = 0.000000
# Beta (=std): 19180
# Number of T/sqrt(n) above 3 stds: 91
# Proportion of T/sqrt(n) above 3 stds: 0.093
# P value = 0.000000
#
#
# Simulation WITH Adjustment Test Results
# Beta (=std): 20240
# Number of T/sqrt(n) above 2 stds: 148
# Proportion of T/sqrt(n) above 2 stds: 0.152
# P value = 0.000000
# Beta (=std): 20240
# Number of T/sqrt(n) above 3 stds: 84
# Proportion of T/sqrt(n) above 3 stds: 0.086
# P value = 0.000000
