# %%
# %run StatTest2_WithSimulation_Setup.ipynb

# %%
data2014 = pd.read_csv("Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = ["WI", "NY", "CA"]
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
df2 = create_df2(states, dfs)

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 5000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for NY 2014-2017 (k=79)")
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 162100.000

# %%
beta1, Mb_index = run_test_against_theoretical(df2, max_beta)
# Out:
# k = 244
# test_stat at this k = 0.08694
#
# At the point of maximum difference with beta = 162100:
# P(|d_i|<v) = 0.7131
# P(|N(0,max_beta^2)|<v) = 0.2172
# Difference = 0.4960
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 152100:
# P(|d_i|<v) = 0.7131
# P(|N(0,max_beta^2)|<v) = 0.2310
# Difference = 0.4821
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 142100:
# P(|d_i|<v) = 0.7131
# P(|N(0,max_beta^2)|<v) = 0.2468
# Difference = 0.4663
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 132100:
# P(|d_i|<v) = 0.7131
# P(|N(0,max_beta^2)|<v) = 0.2648
# Difference = 0.4483
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 122100:
# P(|d_i|<v) = 0.6967
# P(|N(0,max_beta^2)|<v) = 0.2681
# Difference = 0.4286
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 112100:
# P(|d_i|<v) = 0.6967
# P(|N(0,max_beta^2)|<v) = 0.2910
# Difference = 0.4057
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 102100:
# P(|d_i|<v) = 0.6967
# P(|N(0,max_beta^2)|<v) = 0.3180
# Difference = 0.3787
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 92100:
# P(|d_i|<v) = 0.6967
# P(|N(0,max_beta^2)|<v) = 0.3503
# Difference = 0.3464
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 82100:
# P(|d_i|<v) = 0.5615
# P(|N(0,max_beta^2)|<v) = 0.2469
# Difference = 0.3146
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 72100:
# P(|d_i|<v) = 0.5615
# P(|N(0,max_beta^2)|<v) = 0.2798
# Difference = 0.2817
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 62100:
# P(|d_i|<v) = 0.4713
# P(|N(0,max_beta^2)|<v) = 0.2227
# Difference = 0.2487
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 52100:
# P(|d_i|<v) = 0.4385
# P(|N(0,max_beta^2)|<v) = 0.2263
# Difference = 0.2123
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 42100:
# P(|d_i|<v) = 0.3607
# P(|N(0,max_beta^2)|<v) = 0.1962
# Difference = 0.1645
#
#
#
# k = 244
#
# At the point of maximum difference with beta = 32100:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1907
# Difference = 0.1126
#
#
#
# k = 244
# test_stat at this k = 0.08694
#
# At the point of maximum difference with beta = 32100:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1907
# Difference = 0.1126
#
#
#
#
# At the point of maximum difference with beta = 32000:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1913
# Difference = 0.1120
#
#
#
#
# At the point of maximum difference with beta = 31900:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1919
# Difference = 0.1114
#
#
#
#
# At the point of maximum difference with beta = 31800:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1925
# Difference = 0.1108
#
#
#
#
# At the point of maximum difference with beta = 31700:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1931
# Difference = 0.1102
#
#
#
#
# At the point of maximum difference with beta = 31600:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1937
# Difference = 0.1096
#
#
#
#
# At the point of maximum difference with beta = 31500:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.1943
# Difference = 0.1090
#
#
#
#
# At the point of maximum difference with beta = 31400:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1661
# Difference = 0.1085
#
#
#
#
# At the point of maximum difference with beta = 31300:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1666
# Difference = 0.1080
#
#
#
#
# At the point of maximum difference with beta = 31200:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1672
# Difference = 0.1074
#
#
#
#
# At the point of maximum difference with beta = 31100:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1677
# Difference = 0.1069
#
#
#
#
# At the point of maximum difference with beta = 31000:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1682
# Difference = 0.1064
#
#
#
#
# At the point of maximum difference with beta = 30900:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1688
# Difference = 0.1058
#
#
#
#
# At the point of maximum difference with beta = 30800:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1693
# Difference = 0.1053
#
#
#
#
# At the point of maximum difference with beta = 30700:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1698
# Difference = 0.1047
#
#
#
#
# At the point of maximum difference with beta = 30600:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1704
# Difference = 0.1042
#
#
#
#
# At the point of maximum difference with beta = 30500:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1709
# Difference = 0.1036
#
#
#
#
# At the point of maximum difference with beta = 30400:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1715
# Difference = 0.1031
#
#
#
#
# At the point of maximum difference with beta = 30300:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1721
# Difference = 0.1025
#
#
#
#
# At the point of maximum difference with beta = 30200:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1726
# Difference = 0.1020
#
#
#
#
# At the point of maximum difference with beta = 30100:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1732
# Difference = 0.1014
#
#
#
#
# At the point of maximum difference with beta = 30000:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1737
# Difference = 0.1008
#
#
#
#
# At the point of maximum difference with beta = 29900:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1743
# Difference = 0.1003
#
#
#
#
# At the point of maximum difference with beta = 29800:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1749
# Difference = 0.0997
#
#
#
#
# At the point of maximum difference with beta = 29700:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1755
# Difference = 0.0991
#
#
#
#
# At the point of maximum difference with beta = 29600:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1761
# Difference = 0.0985
#
#
#
#
# At the point of maximum difference with beta = 29500:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1766
# Difference = 0.0979
#
#
#
#
# At the point of maximum difference with beta = 29400:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1772
# Difference = 0.0974
#
#
#
#
# At the point of maximum difference with beta = 29300:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1778
# Difference = 0.0968
#
#
#
#
# At the point of maximum difference with beta = 29200:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1784
# Difference = 0.0962
#
#
#
#
# At the point of maximum difference with beta = 29100:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1790
# Difference = 0.0956
#
#
#
#
# At the point of maximum difference with beta = 29000:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1796
# Difference = 0.0950
#
#
#
#
# At the point of maximum difference with beta = 28900:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1802
# Difference = 0.0943
#
#
#
#
# At the point of maximum difference with beta = 28800:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1809
# Difference = 0.0937
#
#
#
#
# At the point of maximum difference with beta = 28700:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1815
# Difference = 0.0931
#
#
#
#
# At the point of maximum difference with beta = 28600:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1821
# Difference = 0.0925
#
#
#
#
# At the point of maximum difference with beta = 28500:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1827
# Difference = 0.0919
#
#
#
#
# At the point of maximum difference with beta = 28400:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1834
# Difference = 0.0912
#
#
#
#
# At the point of maximum difference with beta = 28300:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1840
# Difference = 0.0906
#
#
#
#
# At the point of maximum difference with beta = 28200:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1846
# Difference = 0.0899
#
#
#
#
# At the point of maximum difference with beta = 28100:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1853
# Difference = 0.0893
#
#
#
#
# At the point of maximum difference with beta = 28000:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1859
# Difference = 0.0887
#
#
#
#
# At the point of maximum difference with beta = 27900:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1866
# Difference = 0.0880
#
#
#
#
# At the point of maximum difference with beta = 27800:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1873
# Difference = 0.0873

# %%
beta1 = beta1+100

this_nb_state = "CAWINY"
theoretical = [special.erf(vi/(beta1*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta1))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (this_nb_state, k))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
df3 = create_df3(states, dfs)

# %%
ratios_c = create_simulation(df3, 20000)
ratios_c2 = create_simulation(df3, 30000)
ratios_c3 = create_simulation(df3, 40000)

# %%
theoretical = [special.erf(vi/(30000*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = 30000")
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = 20k, 5 times")
plt.plot(v, ratios_c2, label="Simulation with es = 30k, 5 times")
plt.plot(v, ratios_c3, label="Simulation with es = 40k, 5 times")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for NY/CA/WI 2014-2017 (k=244)")
plt.legend()

# %%
run_test_against_simulation(df2, beta1)
# Out:
# k = 244
# test_stat at this k = 0.08694
#
# At the point of maximum difference with beta = 27800:
# P(|d_i|<v) = 0.2746
# P(|N(0,max_beta^2)|<v) = 0.1737
# Difference = 0.0918
#
#
#
#
# At the point of maximum difference with beta = 27800:
# P(|d_i|<v) = 0.2623
# P(|N(0,max_beta^2)|<v) = 0.1637
# Difference = 0.1016
#
#
#
#
# At the point of maximum difference with beta = 27700:
# P(|d_i|<v) = 0.2705
# P(|N(0,max_beta^2)|<v) = 0.1704
# Difference = 0.1000
#
#
#
#
# At the point of maximum difference with beta = 27600:
# P(|d_i|<v) = 0.3033
# P(|N(0,max_beta^2)|<v) = 0.2038
# Difference = 0.0984
#
#
#
#
# At the point of maximum difference with beta = 27500:
# P(|d_i|<v) = 0.2705
# P(|N(0,max_beta^2)|<v) = 0.1704
# Difference = 0.0984
# (27400, 49)

# %%
run_binom_stat_test2(beta1, df2.values)
# Out:
# Number of above 2: 65
# Proportion of above 2: 0.266
# P value = 0.000000
