# %%
# %run ../StatTest2_WithSimulation_Setup.ipynb
# Out:
# {0: ['ME', 'IL', 'PA', 'GA', 'OK', 'DE', 'WA', 'CT', 'OH', 'VA', 'NE', 'MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'SC', 'RI', 'AK', 'KY', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 1: ['SD', 'IL', 'PA', 'NH', 'NM', 'NV', 'OK', 'UT', 'CT', 'OH', 'VA', 'OR', 'CO', 'IN', 'HI', 'AL', 'RI', 'AK', 'LA', 'MN', 'IA', 'AR', 'WV'], 2: ['MI', 'ME', 'WY', 'DC', 'TX', 'AZ', 'NC', 'WA', 'OR', 'CO', 'MT', 'ND', 'TN', 'SC', 'AL', 'NY', 'KY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 3: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'GA', 'AZ', 'NM', 'NC', 'NV', 'DE', 'UT', 'NE', 'CA', 'MD', 'TN', 'NY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO']}
# {0: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'AZ', 'NM', 'NC', 'NV', 'UT', 'OR', 'CO', 'TN', 'AL', 'NY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 1: ['MI', 'ME', 'WY', 'DC', 'TX', 'GA', 'AZ', 'NC', 'DE', 'WA', 'NE', 'MT', 'CA', 'ND', 'MD', 'TN', 'SC', 'NY', 'KY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO'], 2: ['SD', 'IL', 'PA', 'NH', 'GA', 'NM', 'NV', 'OK', 'DE', 'UT', 'CT', 'OH', 'VA', 'NE', 'IN', 'CA', 'HI', 'MD', 'RI', 'AK', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 3: ['ME', 'IL', 'PA', 'OK', 'WA', 'CT', 'OH', 'VA', 'OR', 'CO', 'MT', 'IN', 'HI', 'ND', 'SC', 'AL', 'RI', 'AK', 'KY', 'LA', 'MN', 'IA', 'AR', 'WV']}

# %%
###################
# LOCAL VARIABLES #
###################

states = ["PA", "WI", "OR", "NV", "FL", "VA", "NY", "AZ", "GA", "CO",
          "MI", "ME", "CA", "MO", "OH", "NM", "CT", "MA", "NE", "HI",
          "MN", "AR", "NJ", "MD", "WA", "UT"]
state_label = "Competitive States"

# %%
data2014 = pd.read_csv("../0-Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("../0-Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("../0-Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("../0-Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new, _ = normalize_empirical_data_to_avg_2017_dollars(dfs, states)
# Out:
# Cbar is 4398.953
# PA 14 Ratio is 1.105
# WI 14 Ratio is 1.127
# OR 14 Ratio is 1.208
# NV 14 Ratio is 1.365
# FL 14 Ratio is 1.199
# VA 14 Ratio is 1.250
# NY 14 Ratio is 0.973
# AZ 14 Ratio is 1.497
# GA 14 Ratio is 1.260
# CO 14 Ratio is 1.203
# MI 14 Ratio is 1.308
# ME 14 Ratio is 1.188
# CA 14 Ratio is 1.154
# MO 14 Ratio is 1.414
# OH 14 Ratio is 1.264
# NM 14 Ratio is 1.142
# CT 14 Ratio is 0.990
# NE 14 Ratio is 1.265
# HI 14 Ratio is 1.175
# MN 14 Ratio is 1.182
# AR 14 Ratio is 1.473
# NJ 14 Ratio is 1.173
# MD 14 Ratio is 1.238
# WA 14 Ratio is 1.199
# UT 14 Ratio is 1.628
# PA 15 Ratio is 1.072
# WI 15 Ratio is 1.099
# OR 15 Ratio is 1.138
# NV 15 Ratio is 1.302
# FL 15 Ratio is 1.162
# VA 15 Ratio is 1.269
# NY 15 Ratio is 0.896
# AZ 15 Ratio is 1.404
# GA 15 Ratio is 1.199
# CO 15 Ratio is 1.185
# MI 15 Ratio is 1.250
# ME 15 Ratio is 1.184
# CA 15 Ratio is 1.117
# MO 15 Ratio is 1.282
# OH 15 Ratio is 1.191
# NM 15 Ratio is 1.108
# CT 15 Ratio is 0.977
# NE 15 Ratio is 1.189
# HI 15 Ratio is 1.086
# MN 15 Ratio is 1.156
# AR 15 Ratio is 1.407
# NJ 15 Ratio is 1.009
# MD 15 Ratio is 1.269
# WA 15 Ratio is 1.156
# UT 15 Ratio is 1.511
# PA 16 Ratio is 1.026
# WI 16 Ratio is 1.053
# OR 16 Ratio is 1.078
# NV 16 Ratio is 1.286
# FL 16 Ratio is 1.112
# VA 16 Ratio is 1.116
# NY 16 Ratio is 0.862
# AZ 16 Ratio is 1.325
# GA 16 Ratio is 1.099
# CO 16 Ratio is 1.176
# MI 16 Ratio is 1.195
# ME 16 Ratio is 1.116
# CA 16 Ratio is 1.051
# MO 16 Ratio is 1.195
# OH 16 Ratio is 1.107
# NM 16 Ratio is 0.971
# CT 16 Ratio is 0.880
# NE 16 Ratio is 1.145
# HI 16 Ratio is 1.044
# MN 16 Ratio is 1.052
# AR 16 Ratio is 1.305
# NJ 16 Ratio is 0.923
# MD 16 Ratio is 1.216
# WA 16 Ratio is 1.134
# UT 16 Ratio is 1.450
# PA 17 Ratio is 0.920
# WI 17 Ratio is 1.005
# OR 17 Ratio is 1.062
# NV 17 Ratio is 1.270
# FL 17 Ratio is 1.046
# VA 17 Ratio is 1.055
# NY 17 Ratio is 0.782
# AZ 17 Ratio is 1.271
# GA 17 Ratio is 1.041
# CO 17 Ratio is 1.100
# MI 17 Ratio is 1.171
# ME 17 Ratio is 1.074
# CA 17 Ratio is 1.015
# MO 17 Ratio is 1.154
# OH 17 Ratio is 1.047
# NM 17 Ratio is 0.945
# CT 17 Ratio is 0.864
# NE 17 Ratio is 1.087
# HI 17 Ratio is 0.977
# MN 17 Ratio is 0.995
# AR 17 Ratio is 1.236
# NJ 17 Ratio is 0.852
# MD 17 Ratio is 1.150
# WA 17 Ratio is 1.115
# UT 17 Ratio is 1.391
# Empirical Transfers Sum = 7356810724.799

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.figure(figsize=(8, 6))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
plt.legend()
plt.xlabel("v")
plt.ylabel("CDF")
plt.show()
# Out:
# beta = 120900.000

# %%
beta_theoretical, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2, False)
# Out:
# k = 1233
# test_stat at this k = 0.03472
#
# At the point of maximum difference with beta = 120900:
# P(|d_i|<v) = 0.8191
# P(|N(0,max_beta^2)|<v) = 0.2871
# Difference = 0.5321
#
#
#
#
# At the point of maximum difference with beta = 110900:
# P(|d_i|<v) = 0.8013
# P(|N(0,max_beta^2)|<v) = 0.2927
# Difference = 0.5085
#
#
#
#
# At the point of maximum difference with beta = 100900:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.2549
# Difference = 0.4848
#
#
#
#
# At the point of maximum difference with beta = 90900:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.2818
# Difference = 0.4579
#
#
#
#
# At the point of maximum difference with beta = 80900:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.3148
# Difference = 0.4248
#
#
#
#
# At the point of maximum difference with beta = 70900:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.3563
# Difference = 0.3833
#
#
#
#
# At the point of maximum difference with beta = 60900:
# P(|d_i|<v) = 0.7397
# P(|N(0,max_beta^2)|<v) = 0.4098
# Difference = 0.3299
#
#
#
#
# At the point of maximum difference with beta = 50900:
# P(|d_i|<v) = 0.6667
# P(|N(0,max_beta^2)|<v) = 0.4036
# Difference = 0.2631
#
#
#
#
# At the point of maximum difference with beta = 40900:
# P(|d_i|<v) = 0.4761
# P(|N(0,max_beta^2)|<v) = 0.2911
# Difference = 0.1849
#
#
#
#
# At the point of maximum difference with beta = 30900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3237
# Difference = 0.1013
#
#
#
#
# At the point of maximum difference with beta = 30900:
# P(|d_i|<v) = 0.4250
# P(|N(0,max_beta^2)|<v) = 0.3237
# Difference = 0.1013
#
#
#
#
# At the point of maximum difference with beta = 28900:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3022
# Difference = 0.0806
#
#
#
#
# At the point of maximum difference with beta = 27900:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3125
# Difference = 0.0703
#
#
#
#
# At the point of maximum difference with beta = 26900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2724
# Difference = 0.0609
#
#
#
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2825
# Difference = 0.0508
#
#
#
#
# At the point of maximum difference with beta = 25800:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2000
# Difference = 0.0498
#
#
#
#
# At the point of maximum difference with beta = 25700:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2008
# Difference = 0.0490
#
#
#
#
# At the point of maximum difference with beta = 25600:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2015
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 25500:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2023
# Difference = 0.0475
#
#
#
#
# At the point of maximum difference with beta = 25400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1731
# Difference = 0.0467
#
#
#
#
# At the point of maximum difference with beta = 25300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1737
# Difference = 0.0461
#
#
#
#
# At the point of maximum difference with beta = 25200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1744
# Difference = 0.0454
#
#
#
#
# At the point of maximum difference with beta = 25100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1751
# Difference = 0.0447
#
#
#
#
# At the point of maximum difference with beta = 25000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1758
# Difference = 0.0440
#
#
#
#
# At the point of maximum difference with beta = 24900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1765
# Difference = 0.0433
#
#
#
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1772
# Difference = 0.0426
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1779
# Difference = 0.0419
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1786
# Difference = 0.0412
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1793
# Difference = 0.0405
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1800
# Difference = 0.0398
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1808
# Difference = 0.0390
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1815
# Difference = 0.0383
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1822
# Difference = 0.0376
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1830
# Difference = 0.0368
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1837
# Difference = 0.0361
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1845
# Difference = 0.0353

# %%
beta_theoretical = beta_theoretical+100

theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.figure(figsize=(8, 6))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
plt.xlabel("v")
plt.ylabel("CDF")
plt.show()

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 23800
# Number of T/sqrt(n) above 2 stds: 212
# Proportion of T/sqrt(n) above 2 stds: 0.172
# P value = 0.000000

# %%
#ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical - 10000)
#ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical)
#ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical + 10000)

# %%
#theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

#plt.figure(figsize=(10, 7))
#plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta_theoretical))
#plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
#plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta_theoretical - 10000))
#plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta_theoretical))
#plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta_theoretical + 10000))
#plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (state_label, len(df2)))
#plt.legend()
#plt.show()

# %%
beta_sims = list()

for i in range(5):
    beta_sim, _= run_test_against_simulation(states, dfs_new, beta_theoretical - 3000, ratios2, False)
    beta_sims.append(beta_sim)
# Out:
# k = 1233
# test_stat at this k = 0.03472
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3293
# P(|N(0,max_beta^2)|<v) = 0.2677
# Difference = 0.0615
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2769
# Difference = 0.0564
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1658
# Difference = 0.0540
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2002
# Difference = 0.0496
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1677
# Difference = 0.0521
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2022
# Difference = 0.0493
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2796
# Difference = 0.0537
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2782
# Difference = 0.0551
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1737
# Difference = 0.0461
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1977
# Difference = 0.0521
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1775
# Difference = 0.0423
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2839
# Difference = 0.0495
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1757
# Difference = 0.0441
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1755
# Difference = 0.0443
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1726
# Difference = 0.0471
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.3293
# P(|N(0,max_beta^2)|<v) = 0.2899
# Difference = 0.0394
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2053
# Difference = 0.0445
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2014
# Difference = 0.0411
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2904
# Difference = 0.0429
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1777
# Difference = 0.0437
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1833
# Difference = 0.0364
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1458
# Difference = 0.0391
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1802
# Difference = 0.0396
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1811
# Difference = 0.0387
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1247
# Difference = 0.0375
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1892
# Difference = 0.0306 NOT > test_stat
# k = 1233
# test_stat at this k = 0.03472
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2810
# Difference = 0.0523
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3779
# P(|N(0,max_beta^2)|<v) = 0.3234
# Difference = 0.0546
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2735
# Difference = 0.0598
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2819
# Difference = 0.0515
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2740
# Difference = 0.0594
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2842
# Difference = 0.0491
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1962
# Difference = 0.0536
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2807
# Difference = 0.0526
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1704
# Difference = 0.0510
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1377
# Difference = 0.0472
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2295
# P(|N(0,max_beta^2)|<v) = 0.1784
# Difference = 0.0511
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1776
# Difference = 0.0422
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1376
# Difference = 0.0473
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1753
# Difference = 0.0461
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1710
# Difference = 0.0488
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2086
# Difference = 0.0428
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1803
# Difference = 0.0395
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2011
# Difference = 0.0414
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1817
# Difference = 0.0397
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1238
# Difference = 0.0384
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1768
# Difference = 0.0430
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1771
# Difference = 0.0427
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1803
# Difference = 0.0411
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1518
# Difference = 0.0331 NOT > test_stat
# k = 1233
# test_stat at this k = 0.03472
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2779
# Difference = 0.0554
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2780
# Difference = 0.0553
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2770
# Difference = 0.0563
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.1986
# Difference = 0.0528
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1879
# Difference = 0.0546
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2765
# Difference = 0.0568
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1877
# Difference = 0.0548
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.1995
# Difference = 0.0520
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1971
# Difference = 0.0527
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2819
# Difference = 0.0515
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2844
# Difference = 0.0489
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2065
# Difference = 0.0449
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2883
# Difference = 0.0450
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1736
# Difference = 0.0462
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1792
# Difference = 0.0422
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2015
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2102
# Difference = 0.0413
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2907
# Difference = 0.0427
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.1809
# P(|N(0,max_beta^2)|<v) = 0.1392
# Difference = 0.0417
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1751
# Difference = 0.0447
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1814
# Difference = 0.0384
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1776
# Difference = 0.0422
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.1638
# P(|N(0,max_beta^2)|<v) = 0.1271
# Difference = 0.0368
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1534
# Difference = 0.0315 NOT > test_stat
# k = 1233
# test_stat at this k = 0.03472
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2749
# Difference = 0.0584
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2761
# Difference = 0.0573
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1978
# Difference = 0.0520
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2775
# Difference = 0.0559
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2803
# Difference = 0.0530
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2755
# Difference = 0.0579
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1646
# Difference = 0.0552
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1993
# Difference = 0.0505
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2007
# Difference = 0.0507
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2006
# Difference = 0.0491
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2042
# Difference = 0.0473
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2057
# Difference = 0.0441
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1959
# Difference = 0.0466
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1715
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1749
# Difference = 0.0449
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1785
# Difference = 0.0413
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.1809
# P(|N(0,max_beta^2)|<v) = 0.1388
# Difference = 0.0420
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.1809
# P(|N(0,max_beta^2)|<v) = 0.1418
# Difference = 0.0391
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1833
# Difference = 0.0365
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1822
# Difference = 0.0376
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1809
# Difference = 0.0389
#
#
#
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.1638
# P(|N(0,max_beta^2)|<v) = 0.1273
# Difference = 0.0366
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1258
# Difference = 0.0364
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2141
# Difference = 0.0373
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1838
# Difference = 0.0360
#
#
#
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1486
# Difference = 0.0363
#
#
#
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2030
# Difference = 0.0468
#
#
#
#
# At the point of maximum difference with beta = 22100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1840
# Difference = 0.0358
#
#
#
#
# At the point of maximum difference with beta = 22000:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1243
# Difference = 0.0379
#
#
#
#
# At the point of maximum difference with beta = 21900:
# P(|d_i|<v) = 0.1573
# P(|N(0,max_beta^2)|<v) = 0.1242
# Difference = 0.0331 NOT > test_stat
# k = 1233
# test_stat at this k = 0.03472
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2713
# Difference = 0.0621
#
#
#
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2790
# Difference = 0.0543
#
#
#
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2750
# Difference = 0.0583
#
#
#
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3577
# P(|N(0,max_beta^2)|<v) = 0.2958
# Difference = 0.0619
#
#
#
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2015
# Difference = 0.0483
#
#
#
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1954
# Difference = 0.0544
#
#
#
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.3593
# P(|N(0,max_beta^2)|<v) = 0.3021
# Difference = 0.0572
#
#
#
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2789
# Difference = 0.0544
#
#
#
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1935
# Difference = 0.0490
#
#
#
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2881
# Difference = 0.0453
#
#
#
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1974
# Difference = 0.0451
#
#
#
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2838
# Difference = 0.0496
#
#
#
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2811
# Difference = 0.0522
#
#
#
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1772
# Difference = 0.0442
#
#
#
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1765
# Difference = 0.0433
#
#
#
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1780
# Difference = 0.0417
#
#
#
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1778
# Difference = 0.0420
#
#
#
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1745
# Difference = 0.0469
#
#
#
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2081
# Difference = 0.0417
#
#
#
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2001
# Difference = 0.0424
#
#
#
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1799
# Difference = 0.0399
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1248
# Difference = 0.0374
#
#
#
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2124
# Difference = 0.0374
#
#
#
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1795
# Difference = 0.0403
#
#
#
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1871
# Difference = 0.0327 NOT > test_stat

# %%
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
# Out:
# Simulation without Adjustment Test Results
# Beta (=std): 22320
# Number of T/sqrt(n) above 2 stds: 223
# Proportion of T/sqrt(n) above 2 stds: 0.181
# P value = 0.000000
# Beta (=std): 22320
# Number of T/sqrt(n) above 3 stds: 121
# Proportion of T/sqrt(n) above 3 stds: 0.098
# P value = 0.000000

# %%
beta_sim_adjs = list()

for i in range(5):
    beta_sim_adj, _, sum_sqrt_a = run_test_against_simulation_adjust_for_imbalances(states, dfs_new,
                                                                   beta_theoretical - 3000, ratios2, False)
    beta_sim_adjs.append(beta_sim_adj)
# Out:
# k = 1233
# test_stat at this k = 0.03472
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2780
# Difference = 0.0553
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3242
# Difference = 0.0586
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3577
# P(|N(0,max_beta^2)|<v) = 0.3029
# Difference = 0.0548
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2770
# Difference = 0.0563
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2725
# Difference = 0.0608
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2773
# Difference = 0.0560
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2295
# P(|N(0,max_beta^2)|<v) = 0.1778
# Difference = 0.0517
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1686
# Difference = 0.0512
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2810
# Difference = 0.0523
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1728
# Difference = 0.0470
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2872
# Difference = 0.0461
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1933
# Difference = 0.0492
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1768
# Difference = 0.0447
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.3293
# P(|N(0,max_beta^2)|<v) = 0.2807
# Difference = 0.0486
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2885
# Difference = 0.0448
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2095
# Difference = 0.0419
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1791
# Difference = 0.0407
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1743
# Difference = 0.0455
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1762
# Difference = 0.0436
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1777
# Difference = 0.0421
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1823
# Difference = 0.0375
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1784
# Difference = 0.0414
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2137
# Difference = 0.0377
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1871
# Difference = 0.0343 NOT > test_stat
# E(|X|) = 2647455557.218
# k = 1233
# test_stat at this k = 0.03472
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2749
# Difference = 0.0584
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1871
# Difference = 0.0554
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3293
# P(|N(0,max_beta^2)|<v) = 0.2776
# Difference = 0.0516
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2808
# Difference = 0.0526
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2785
# Difference = 0.0549
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.1966
# Difference = 0.0548
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1731
# Difference = 0.0483
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2025
# Difference = 0.0489
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3779
# P(|N(0,max_beta^2)|<v) = 0.3276
# Difference = 0.0503
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1979
# Difference = 0.0519
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.1941
# Difference = 0.0484
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2090
# Difference = 0.0424
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1794
# Difference = 0.0420
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2858
# Difference = 0.0475
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2107
# Difference = 0.0408
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2002
# Difference = 0.0423
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2069
# Difference = 0.0429
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2963
# Difference = 0.0370
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1758
# Difference = 0.0440
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1766
# Difference = 0.0432
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1754
# Difference = 0.0444
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1749
# Difference = 0.0449
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1770
# Difference = 0.0428
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1499
# Difference = 0.0350
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1883
# Difference = 0.0315 NOT > test_stat
# E(|X|) = 2635689088.075
# k = 1233
# test_stat at this k = 0.03472
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3828
# P(|N(0,max_beta^2)|<v) = 0.3254
# Difference = 0.0574
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2767
# Difference = 0.0567
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2795
# Difference = 0.0539
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2778
# Difference = 0.0555
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2785
# Difference = 0.0548
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3747
# P(|N(0,max_beta^2)|<v) = 0.3195
# Difference = 0.0552
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2028
# Difference = 0.0487
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2004
# Difference = 0.0494
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2849
# Difference = 0.0484
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2855
# Difference = 0.0479
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2058
# Difference = 0.0456
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2041
# Difference = 0.0457
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2888
# Difference = 0.0446
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2295
# P(|N(0,max_beta^2)|<v) = 0.1846
# Difference = 0.0449
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1788
# Difference = 0.0410
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2024
# Difference = 0.0401
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1806
# Difference = 0.0391
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2016
# Difference = 0.0409
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1785
# Difference = 0.0413
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1778
# Difference = 0.0420
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1793
# Difference = 0.0404
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1843
# Difference = 0.0355
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1798
# Difference = 0.0400
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1492
# Difference = 0.0357
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1285
# Difference = 0.0337 NOT > test_stat
# E(|X|) = 2635689088.075
# k = 1233
# test_stat at this k = 0.03472
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2794
# Difference = 0.0540
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2821
# Difference = 0.0512
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2792
# Difference = 0.0542
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1684
# Difference = 0.0530
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2726
# Difference = 0.0608
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2764
# Difference = 0.0569
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1712
# Difference = 0.0502
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1705
# Difference = 0.0493
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2792
# Difference = 0.0542
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2882
# Difference = 0.0451
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2855
# Difference = 0.0479
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2863
# Difference = 0.0470
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1754
# Difference = 0.0460
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1742
# Difference = 0.0472
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2905
# Difference = 0.0428
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1723
# Difference = 0.0475
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2920
# Difference = 0.0414
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1760
# Difference = 0.0438
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.1622
# P(|N(0,max_beta^2)|<v) = 0.1202
# Difference = 0.0420
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2214
# P(|N(0,max_beta^2)|<v) = 0.1763
# Difference = 0.0451
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2015
# Difference = 0.0410
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1778
# Difference = 0.0420
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.1638
# P(|N(0,max_beta^2)|<v) = 0.1275
# Difference = 0.0363
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1733
# Difference = 0.0464
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1851
# Difference = 0.0347 NOT > test_stat
# E(|X|) = 2635689088.075
# k = 1233
# test_stat at this k = 0.03472
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24800:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2717
# Difference = 0.0616
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24700:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1994
# Difference = 0.0504
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2726
# Difference = 0.0608
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24500:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.1916
# Difference = 0.0582
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24400:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2746
# Difference = 0.0588
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24300:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2816
# Difference = 0.0517
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24200:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2758
# Difference = 0.0575
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1679
# Difference = 0.0519
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 24000:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1717
# Difference = 0.0481
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23900:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2021
# Difference = 0.0477
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23800:
# P(|d_i|<v) = 0.2498
# P(|N(0,max_beta^2)|<v) = 0.2028
# Difference = 0.0470
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23700:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2825
# Difference = 0.0509
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23600:
# P(|d_i|<v) = 0.3333
# P(|N(0,max_beta^2)|<v) = 0.2878
# Difference = 0.0456
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1749
# Difference = 0.0449
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1785
# Difference = 0.0413
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23300:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2032
# Difference = 0.0393
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23200:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1756
# Difference = 0.0442
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23100:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1765
# Difference = 0.0433
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 23000:
# P(|d_i|<v) = 0.2514
# P(|N(0,max_beta^2)|<v) = 0.2110
# Difference = 0.0404
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22900:
# P(|d_i|<v) = 0.2425
# P(|N(0,max_beta^2)|<v) = 0.2001
# Difference = 0.0424
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22800:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1823
# Difference = 0.0375
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22700:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1828
# Difference = 0.0370
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22600:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1822
# Difference = 0.0376
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22500:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1778
# Difference = 0.0420
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22400:
# P(|d_i|<v) = 0.2198
# P(|N(0,max_beta^2)|<v) = 0.1805
# Difference = 0.0393
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22300:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1475
# Difference = 0.0374
#
#
#
# Sum sqrt(a) = 147470.821
#
# At the point of maximum difference with beta = 22200:
# P(|d_i|<v) = 0.1849
# P(|N(0,max_beta^2)|<v) = 0.1518
# Difference = 0.0331 NOT > test_stat
# E(|X|) = 2612156149.788

# %%
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Simulation WITH Adjustment Test Results
# Beta (=std): 22380
# Number of T/sqrt(n) above 2 stds: 223
# Proportion of T/sqrt(n) above 2 stds: 0.181
# P value = 0.000000
# Beta (=std): 22380
# Number of T/sqrt(n) above 3 stds: 121
# Proportion of T/sqrt(n) above 3 stds: 0.098
# P value = 0.000000

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
run_binom_stat_test3(beta_theoretical, df2.values)
print("\n")
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
print("\n")
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 23800
# Number of T/sqrt(n) above 2 stds: 212
# Proportion of T/sqrt(n) above 2 stds: 0.172
# P value = 0.000000
# Beta (=std): 23800
# Number of T/sqrt(n) above 3 stds: 107
# Proportion of T/sqrt(n) above 3 stds: 0.087
# P value = 0.000000
#
#
# Simulation without Adjustment Test Results
# Beta (=std): 22320
# Number of T/sqrt(n) above 2 stds: 223
# Proportion of T/sqrt(n) above 2 stds: 0.181
# P value = 0.000000
# Beta (=std): 22320
# Number of T/sqrt(n) above 3 stds: 121
# Proportion of T/sqrt(n) above 3 stds: 0.098
# P value = 0.000000
#
#
# Simulation WITH Adjustment Test Results
# Beta (=std): 22380
# Number of T/sqrt(n) above 2 stds: 223
# Proportion of T/sqrt(n) above 2 stds: 0.181
# P value = 0.000000
# Beta (=std): 22380
# Number of T/sqrt(n) above 3 stds: 121
# Proportion of T/sqrt(n) above 3 stds: 0.098
# P value = 0.000000

# %%
np.mean(beta_sims) * sum_sqrt_a * np.sqrt(2) / np.sqrt(np.pi)
# Out:
# 2626275912.760089

# %%
np.mean(beta_sim_adjs) * sum_sqrt_a * np.sqrt(2) / np.sqrt(np.pi)
# Out:
# 2633335794.246003

# %%
beta_sims
# Out:
# [22300, 22500, 22500, 21900, 22400]

# %%
beta_sim_adjs
# Out:
# [22500, 22400, 22400, 22400, 22200]
