# %%
# %run ../StatTest2_WithSimulation_Setup.ipynb
# Out:
# {0: ['ME', 'IL', 'PA', 'GA', 'OK', 'DE', 'WA', 'CT', 'OH', 'VA', 'NE', 'MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'SC', 'RI', 'AK', 'KY', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 1: ['SD', 'IL', 'PA', 'NH', 'NM', 'NV', 'OK', 'UT', 'CT', 'OH', 'VA', 'OR', 'CO', 'IN', 'HI', 'AL', 'RI', 'AK', 'LA', 'MN', 'IA', 'AR', 'WV'], 2: ['MI', 'ME', 'WY', 'DC', 'TX', 'AZ', 'NC', 'WA', 'OR', 'CO', 'MT', 'ND', 'TN', 'SC', 'AL', 'NY', 'KY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 3: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'GA', 'AZ', 'NM', 'NC', 'NV', 'DE', 'UT', 'NE', 'CA', 'MD', 'TN', 'NY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO']}
# {0: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'AZ', 'NM', 'NC', 'NV', 'UT', 'OR', 'CO', 'TN', 'AL', 'NY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 1: ['MI', 'ME', 'WY', 'DC', 'TX', 'GA', 'AZ', 'NC', 'DE', 'WA', 'NE', 'MT', 'CA', 'ND', 'MD', 'TN', 'SC', 'NY', 'KY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO'], 2: ['SD', 'IL', 'PA', 'NH', 'GA', 'NM', 'NV', 'OK', 'DE', 'UT', 'CT', 'OH', 'VA', 'NE', 'IN', 'CA', 'HI', 'MD', 'RI', 'AK', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 3: ['ME', 'IL', 'PA', 'OK', 'WA', 'CT', 'OH', 'VA', 'OR', 'CO', 'MT', 'IN', 'HI', 'ND', 'SC', 'AL', 'RI', 'AK', 'KY', 'LA', 'MN', 'IA', 'AR', 'WV']}

# %%
###################
# LOCAL VARIABLES #
###################

states = ["WI"]
state_label = "WI"

# %%
data2014 = pd.read_csv("../0-Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("../0-Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("../0-Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("../0-Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new, _ = normalize_empirical_data_to_avg_2017_dollars(dfs, states)
# Out:
# Cbar is 4398.953
# WI 14 Ratio is 1.127
# WI 15 Ratio is 1.099
# WI 16 Ratio is 1.053
# WI 17 Ratio is 1.005
# Empirical Transfers Sum = 130331575.144

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.figure(figsize=(8, 6))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
plt.legend()
plt.xlabel("v")
plt.ylabel("CDF")
plt.show()
# Out:
# beta = 25900.000

# %%
beta_theoretical, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2, False)
# Out:
# k = 104
# test_stat at this k = 0.11836
#
# At the point of maximum difference with beta = 25900:
# P(|d_i|<v) = 0.5385
# P(|N(0,max_beta^2)|<v) = 0.2467
# Difference = 0.2918
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3249
# Difference = 0.1655
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3249
# Difference = 0.1655
#
#
#
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3453
# Difference = 0.1451
#
#
#
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3587
# Difference = 0.1221
#
#
#
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3611
# Difference = 0.1197

# %%
beta_theoretical = beta_theoretical+100

theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.figure(figsize=(8, 6))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=%d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
plt.xlabel("v")
plt.ylabel("CDF")
plt.show()

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 13800
# Number of T/sqrt(n) above 2 stds: 19
# Proportion of T/sqrt(n) above 2 stds: 0.183
# P value = 0.000000

# %%
ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical - 10000)
ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical)
ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical + 10000)
# Out:
# Sum sqrt(a) = 8517.372
# Sum sqrt(a) = 8517.372
# Sum sqrt(a) = 8517.372

# %%
theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta_theoretical - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta_theoretical))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta_theoretical + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (state_label, len(df2)))
plt.legend()
plt.show()

# %%
beta_sims = list()

for i in range(5):
    beta_sim, _= run_test_against_simulation(states, dfs_new, beta_theoretical, ratios2, False)
    beta_sims.append(beta_sim)
# Out:
# k = 104
# test_stat at this k = 0.11836
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2763
# Difference = 0.2237
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2603
# Difference = 0.2301
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2833
# Difference = 0.2167
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2750
# Difference = 0.2154
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2955
# Difference = 0.2141
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2936
# Difference = 0.1968
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2917
# Difference = 0.2083
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3006
# Difference = 0.1994
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2910
# Difference = 0.2090
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2929
# Difference = 0.1974
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3083
# Difference = 0.1917
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2968
# Difference = 0.1936
#
#
#
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2974
# Difference = 0.1929
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2904
# Difference = 0.1904
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2936
# Difference = 0.1968
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3096
# Difference = 0.1904
#
#
#
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2929
# Difference = 0.2071
#
#
#
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3282
# Difference = 0.1718
#
#
#
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3192
# Difference = 0.1712
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2897
# Difference = 0.1910
#
#
#
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1731
#
#
#
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3154
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1667
#
#
#
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3026
# Difference = 0.1878
#
#
#
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1827
#
#
#
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3141
# Difference = 0.1667
#
#
#
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1583
#
#
#
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3365
# Difference = 0.1635
#
#
#
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3321
# Difference = 0.1487
#
#
#
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3622
# Difference = 0.1474
#
#
#
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3365
# Difference = 0.1442
#
#
#
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1513
#
#
#
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3679
# Difference = 0.1321
#
#
#
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1513
#
#
#
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3641
# Difference = 0.1263
#
#
#
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3442
# Difference = 0.1365
#
#
#
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3590
# Difference = 0.1410
#
#
#
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1436
#
#
#
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3429
# Difference = 0.1378
#
#
#
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1391
#
#
#
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3500
# Difference = 0.1308
#
#
#
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3404
# Difference = 0.1404
#
#
#
#
# At the point of maximum difference with beta = 13300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3571
# Difference = 0.1333
#
#
#
#
# At the point of maximum difference with beta = 13200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3846
# Difference = 0.1058 NOT > test_stat
# k = 104
# test_stat at this k = 0.11836
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2788
# Difference = 0.2115
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1878
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2949
# Difference = 0.2147
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3135
# Difference = 0.1865
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2647
# Difference = 0.2160
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2814
# Difference = 0.2090
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2891
# Difference = 0.2109
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3000
# Difference = 0.1904
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2994
# Difference = 0.1910
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.5385
# P(|N(0,max_beta^2)|<v) = 0.3532
# Difference = 0.1853
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2994
# Difference = 0.2006
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3038
# Difference = 0.1865
#
#
#
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2827
# Difference = 0.2077
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2962
# Difference = 0.1942
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2987
# Difference = 0.2013
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3135
# Difference = 0.1865
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3071
# Difference = 0.1737
#
#
#
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3160
# Difference = 0.1840
#
#
#
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3141
# Difference = 0.1859
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3077
# Difference = 0.1827
#
#
#
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1667
#
#
#
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3212
# Difference = 0.1788
#
#
#
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3071
# Difference = 0.1833
#
#
#
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2962
# Difference = 0.1942
#
#
#
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3212
# Difference = 0.1692
#
#
#
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3558
# Difference = 0.1538
#
#
#
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3321
# Difference = 0.1583
#
#
#
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1667
#
#
#
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1545
#
#
#
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3237
# Difference = 0.1667
#
#
#
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3519
# Difference = 0.1385
#
#
#
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3308
# Difference = 0.1500
#
#
#
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.1615
#
#
#
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3244
# Difference = 0.1564
#
#
#
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3455
# Difference = 0.1353
#
#
#
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3628
# Difference = 0.1276
#
#
#
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3635
# Difference = 0.1462
#
#
#
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3442
# Difference = 0.1365
#
#
#
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3404
# Difference = 0.1500
#
#
#
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1487
#
#
#
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3731
# Difference = 0.1365
#
#
#
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3577
# Difference = 0.1327
#
#
#
#
# At the point of maximum difference with beta = 13300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3641
# Difference = 0.1263
#
#
#
#
# At the point of maximum difference with beta = 13200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3487
# Difference = 0.1417
#
#
#
#
# At the point of maximum difference with beta = 13100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3622
# Difference = 0.1186
#
#
#
#
# At the point of maximum difference with beta = 13000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3532
# Difference = 0.1372
#
#
#
#
# At the point of maximum difference with beta = 12900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3628
# Difference = 0.1179 NOT > test_stat
# k = 104
# test_stat at this k = 0.11836
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2923
# Difference = 0.2173
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2917
# Difference = 0.2083
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2692
# Difference = 0.2308
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2917
# Difference = 0.2083
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3045
# Difference = 0.2051
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3141
# Difference = 0.1955
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2846
# Difference = 0.2058
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2968
# Difference = 0.2128
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2840
# Difference = 0.1968
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3147
# Difference = 0.1949
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2865
# Difference = 0.2038
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3109
# Difference = 0.1987
#
#
#
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3026
# Difference = 0.1974
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3083
# Difference = 0.1724
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1846
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2904
# Difference = 0.1904
#
#
#
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2885
# Difference = 0.2019
#
#
#
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3231
# Difference = 0.1769
#
#
#
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2846
# Difference = 0.1962
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3096
# Difference = 0.1808
#
#
#
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1737
#
#
#
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3205
# Difference = 0.1795
#
#
#
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3160
# Difference = 0.1744
#
#
#
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3199
# Difference = 0.1609
#
#
#
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3340
# Difference = 0.1660
#
#
#
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3135
# Difference = 0.1769
#
#
#
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3186
# Difference = 0.1622
#
#
#
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1686
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3442
# Difference = 0.1558
#
#
#
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3391
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3545
# Difference = 0.1455
#
#
#
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1513
#
#
#
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3301
# Difference = 0.1506
#
#
#
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3365
# Difference = 0.1635
#
#
#
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3788
# Difference = 0.1212
#
#
#
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1487
#
#
#
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3179
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3481
# Difference = 0.1519
#
#
#
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3500
# Difference = 0.1404
#
#
#
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3846
# Difference = 0.1250
#
#
#
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3263
# Difference = 0.1545
#
#
#
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3564
# Difference = 0.1436
#
#
#
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3487
# Difference = 0.1321
#
#
#
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3782
# Difference = 0.1122 NOT > test_stat
# k = 104
# test_stat at this k = 0.11836
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2609
# Difference = 0.2295
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2769
# Difference = 0.2231
#
#
#
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1974
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2878
# Difference = 0.2218
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2763
# Difference = 0.2141
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2692
# Difference = 0.2212
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2840
# Difference = 0.2160
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2808
# Difference = 0.2096
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2904
# Difference = 0.2096
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3135
# Difference = 0.1865
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3071
# Difference = 0.1929
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3045
# Difference = 0.1955
#
#
#
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3397
# Difference = 0.1699
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1878
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3006
# Difference = 0.1994
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1923
#
#
#
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3064
# Difference = 0.1840
#
#
#
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3141
# Difference = 0.1859
#
#
#
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2949
# Difference = 0.1859
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2936
# Difference = 0.1968
#
#
#
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2955
# Difference = 0.1853
#
#
#
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3077
# Difference = 0.1923
#
#
#
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3314
# Difference = 0.1686
#
#
#
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2968
# Difference = 0.1936
#
#
#
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3321
# Difference = 0.1583
#
#
#
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2955
# Difference = 0.1949
#
#
#
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1667
#
#
#
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1686
#
#
#
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3154
# Difference = 0.1750
#
#
#
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1737
#
#
#
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3224
# Difference = 0.1679
#
#
#
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1532
#
#
#
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1654
#
#
#
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3308
# Difference = 0.1596
#
#
#
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3436
# Difference = 0.1564
#
#
#
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3635
# Difference = 0.1365
#
#
#
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3513
# Difference = 0.1391
#
#
#
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3481
# Difference = 0.1423
#
#
#
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3346
# Difference = 0.1462
#
#
#
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3462
# Difference = 0.1346
#
#
#
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3442
# Difference = 0.1462
#
#
#
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3513
# Difference = 0.1295
#
#
#
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3526
# Difference = 0.1378
#
#
#
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3449
# Difference = 0.1359
#
#
#
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3756
# Difference = 0.1147 NOT > test_stat
# k = 104
# test_stat at this k = 0.11836
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2712
# Difference = 0.2192
#
#
#
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3006
# Difference = 0.2090
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2782
# Difference = 0.2218
#
#
#
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2667
# Difference = 0.2333
#
#
#
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2865
# Difference = 0.2135
#
#
#
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2699
# Difference = 0.2109
#
#
#
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2833
# Difference = 0.2071
#
#
#
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2808
# Difference = 0.2192
#
#
#
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2968
# Difference = 0.2032
#
#
#
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2929
# Difference = 0.1974
#
#
#
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2923
# Difference = 0.1981
#
#
#
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2936
# Difference = 0.1968
#
#
#
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2994
# Difference = 0.1910
#
#
#
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3006
# Difference = 0.1897
#
#
#
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2833
# Difference = 0.2071
#
#
#
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2885
# Difference = 0.1923
#
#
#
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2968
# Difference = 0.1936
#
#
#
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2942
# Difference = 0.1865
#
#
#
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3186
# Difference = 0.1814
#
#
#
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3109
# Difference = 0.1795
#
#
#
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3192
# Difference = 0.1712
#
#
#
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3378
# Difference = 0.1718
#
#
#
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3192
# Difference = 0.1615
#
#
#
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3058
# Difference = 0.1942
#
#
#
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3115
# Difference = 0.1788
#
#
#
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1641
#
#
#
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3032
# Difference = 0.1776
#
#
#
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3231
# Difference = 0.1769
#
#
#
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3635
# Difference = 0.1365
#
#
#
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3282
# Difference = 0.1814
#
#
#
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3705
# Difference = 0.1391
#
#
#
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3321
# Difference = 0.1679
#
#
#
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3269
# Difference = 0.1538
#
#
#
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3878
# Difference = 0.1122 NOT > test_stat

# %%
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
# Out:
# Simulation without Adjustment Test Results
# Beta (=std): 13480
# Number of T/sqrt(n) above 2 stds: 19
# Proportion of T/sqrt(n) above 2 stds: 0.183
# P value = 0.000000
# Beta (=std): 13480
# Number of T/sqrt(n) above 3 stds: 12
# Proportion of T/sqrt(n) above 3 stds: 0.115
# P value = 0.000000

# %%
beta_sim_adjs = list()

for i in range(5):
    beta_sim_adj, _, sum_sqrt_a = run_test_against_simulation_adjust_for_imbalances(states, dfs_new,
                                                                   beta_theoretical, ratios2, False)
    beta_sim_adjs.append(beta_sim_adj)
# Out:
# k = 104
# test_stat at this k = 0.11836
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2962
# Difference = 0.2135
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2833
# Difference = 0.2071
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2705
# Difference = 0.2295
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2981
# Difference = 0.2019
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2776
# Difference = 0.2128
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2878
# Difference = 0.2026
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2737
# Difference = 0.2359
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2949
# Difference = 0.2051
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2872
# Difference = 0.1936
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3147
# Difference = 0.1853
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3269
# Difference = 0.1731
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2692
# Difference = 0.2308
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3186
# Difference = 0.1910
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3013
# Difference = 0.1987
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3032
# Difference = 0.1776
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3077
# Difference = 0.1827
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3192
# Difference = 0.1904
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2724
# Difference = 0.2179
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2987
# Difference = 0.2013
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2955
# Difference = 0.1949
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3436
# Difference = 0.1660
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3103
# Difference = 0.1801
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2987
# Difference = 0.1821
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3308
# Difference = 0.1692
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1583
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3308
# Difference = 0.1596
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1641
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3346
# Difference = 0.1654
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3276
# Difference = 0.1628
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1532
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3308
# Difference = 0.1692
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3365
# Difference = 0.1538
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3237
# Difference = 0.1667
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3199
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3660
# Difference = 0.1340
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3391
# Difference = 0.1417
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3545
# Difference = 0.1359
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3417
# Difference = 0.1487
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3494
# Difference = 0.1314
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3583
# Difference = 0.1224
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3462
# Difference = 0.1346
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1558
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3577
# Difference = 0.1327
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3731
# Difference = 0.1269
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3679
# Difference = 0.1224
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3526
# Difference = 0.1378
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3558
# Difference = 0.1250
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3596
# Difference = 0.1308
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 12900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3532
# Difference = 0.1276
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 12800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3891
# Difference = 0.1013 NOT > test_stat
# E(|X|) = 86987255.840
# k = 104
# test_stat at this k = 0.11836
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2686
# Difference = 0.2218
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2923
# Difference = 0.2077
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3038
# Difference = 0.1962
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2827
# Difference = 0.2173
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2987
# Difference = 0.2109
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2865
# Difference = 0.2135
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2750
# Difference = 0.2154
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2788
# Difference = 0.2019
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2929
# Difference = 0.2071
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2846
# Difference = 0.2250
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2788
# Difference = 0.2019
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3160
# Difference = 0.1840
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3019
# Difference = 0.1885
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3205
# Difference = 0.1891
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1750
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3109
# Difference = 0.1891
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3154
# Difference = 0.1750
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2974
# Difference = 0.1833
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3013
# Difference = 0.1987
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3301
# Difference = 0.1699
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3429
# Difference = 0.1571
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3263
# Difference = 0.1545
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3083
# Difference = 0.1821
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3301
# Difference = 0.1699
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3391
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3231
# Difference = 0.1769
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3231
# Difference = 0.1577
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3429
# Difference = 0.1474
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3500
# Difference = 0.1500
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1724
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3538
# Difference = 0.1365
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3500
# Difference = 0.1308
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3583
# Difference = 0.1321
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3583
# Difference = 0.1513
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3244
# Difference = 0.1564
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3641
# Difference = 0.1359
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3327
# Difference = 0.1481
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3205
# Difference = 0.1795
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3564
# Difference = 0.1340
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1436
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3436
# Difference = 0.1468
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3404
# Difference = 0.1404
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3558
# Difference = 0.1250
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3801
# Difference = 0.1103 NOT > test_stat
# E(|X|) = 91064783.457
# k = 104
# test_stat at this k = 0.11836
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2853
# Difference = 0.2147
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2840
# Difference = 0.2256
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2673
# Difference = 0.2231
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2942
# Difference = 0.2058
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3147
# Difference = 0.1853
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2737
# Difference = 0.2167
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2872
# Difference = 0.2224
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2891
# Difference = 0.2109
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2808
# Difference = 0.2192
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2763
# Difference = 0.2141
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2846
# Difference = 0.1962
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3032
# Difference = 0.1872
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2885
# Difference = 0.2019
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1878
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3179
# Difference = 0.1724
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3224
# Difference = 0.1776
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3237
# Difference = 0.1859
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3321
# Difference = 0.1679
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.1712
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3122
# Difference = 0.1974
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3064
# Difference = 0.1744
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3077
# Difference = 0.1731
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3314
# Difference = 0.1782
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3218
# Difference = 0.1686
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3462
# Difference = 0.1538
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3218
# Difference = 0.1686
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3179
# Difference = 0.1724
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3135
# Difference = 0.1673
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3487
# Difference = 0.1513
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3199
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3641
# Difference = 0.1359
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3590
# Difference = 0.1506
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3224
# Difference = 0.1583
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3487
# Difference = 0.1513
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3263
# Difference = 0.1545
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3462
# Difference = 0.1442
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3423
# Difference = 0.1481
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3449
# Difference = 0.1455
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3295
# Difference = 0.1609
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1340
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3532
# Difference = 0.1468
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3564
# Difference = 0.1340
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3615
# Difference = 0.1192
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13400:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3429
# Difference = 0.1378
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3692
# Difference = 0.1212
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3788
# Difference = 0.1115 NOT > test_stat
# E(|X|) = 89705607.585
# k = 104
# test_stat at this k = 0.11836
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2872
# Difference = 0.2128
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2763
# Difference = 0.2237
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2962
# Difference = 0.2135
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3064
# Difference = 0.2032
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2917
# Difference = 0.2083
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2692
# Difference = 0.2212
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3032
# Difference = 0.2064
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2840
# Difference = 0.2064
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2782
# Difference = 0.2122
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.2962
# Difference = 0.2135
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2699
# Difference = 0.2109
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2827
# Difference = 0.2077
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2955
# Difference = 0.2045
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3244
# Difference = 0.1853
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3096
# Difference = 0.1808
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2942
# Difference = 0.1865
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3064
# Difference = 0.1936
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3019
# Difference = 0.1788
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3045
# Difference = 0.1859
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1833
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3186
# Difference = 0.1814
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2955
# Difference = 0.1853
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3141
# Difference = 0.1763
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3154
# Difference = 0.1654
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3173
# Difference = 0.1731
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3160
# Difference = 0.1744
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3359
# Difference = 0.1545
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3205
# Difference = 0.1603
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3212
# Difference = 0.1788
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3404
# Difference = 0.1692
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3462
# Difference = 0.1442
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3205
# Difference = 0.1699
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1474
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3250
# Difference = 0.1558
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3397
# Difference = 0.1410
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3288
# Difference = 0.1519
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3442
# Difference = 0.1558
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3314
# Difference = 0.1494
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3372
# Difference = 0.1436
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3532
# Difference = 0.1276
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3551
# Difference = 0.1256
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3513
# Difference = 0.1391
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3737
# Difference = 0.1071 NOT > test_stat
# E(|X|) = 92423959.330
# k = 104
# test_stat at this k = 0.11836
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17800:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2904
# Difference = 0.2096
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2904
# Difference = 0.2000
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2949
# Difference = 0.2051
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17500:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2929
# Difference = 0.2071
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2724
# Difference = 0.2179
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3051
# Difference = 0.1853
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3045
# Difference = 0.1859
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.2833
# Difference = 0.2167
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 17000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1833
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16900:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2840
# Difference = 0.1968
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2827
# Difference = 0.1981
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.2897
# Difference = 0.1910
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16600:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3186
# Difference = 0.1910
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16500:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1929
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3032
# Difference = 0.1872
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16300:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3090
# Difference = 0.1910
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16200:
# P(|d_i|<v) = 0.5096
# P(|N(0,max_beta^2)|<v) = 0.3090
# Difference = 0.2006
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16100:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3115
# Difference = 0.1885
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 16000:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3154
# Difference = 0.1750
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15900:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3167
# Difference = 0.1833
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3006
# Difference = 0.1801
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3083
# Difference = 0.1724
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3269
# Difference = 0.1635
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3263
# Difference = 0.1545
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15400:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.2923
# Difference = 0.1981
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3269
# Difference = 0.1635
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3327
# Difference = 0.1577
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3186
# Difference = 0.1718
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 15000:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3179
# Difference = 0.1628
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3353
# Difference = 0.1551
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14800:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1571
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14700:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3391
# Difference = 0.1417
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14600:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3256
# Difference = 0.1647
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14500:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3436
# Difference = 0.1468
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14400:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3333
# Difference = 0.1667
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14300:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3224
# Difference = 0.1679
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14200:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3468
# Difference = 0.1436
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14100:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3353
# Difference = 0.1551
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 14000:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3513
# Difference = 0.1487
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13900:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3474
# Difference = 0.1429
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13800:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3346
# Difference = 0.1462
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13700:
# P(|d_i|<v) = 0.4904
# P(|N(0,max_beta^2)|<v) = 0.3571
# Difference = 0.1333
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13600:
# P(|d_i|<v) = 0.5000
# P(|N(0,max_beta^2)|<v) = 0.3776
# Difference = 0.1224
#
#
#
# Sum sqrt(a) = 8517.372
#
# At the point of maximum difference with beta = 13500:
# P(|d_i|<v) = 0.4808
# P(|N(0,max_beta^2)|<v) = 0.3635
# Difference = 0.1173 NOT > test_stat
# E(|X|) = 91744371.393

# %%
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Simulation WITH Adjustment Test Results
# Beta (=std): 13300
# Number of T/sqrt(n) above 2 stds: 21
# Proportion of T/sqrt(n) above 2 stds: 0.202
# P value = 0.000000
# Beta (=std): 13300
# Number of T/sqrt(n) above 3 stds: 12
# Proportion of T/sqrt(n) above 3 stds: 0.115
# P value = 0.000000

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
run_binom_stat_test3(beta_theoretical, df2.values)
print("\n")
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
print("\n")
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 13800
# Number of T/sqrt(n) above 2 stds: 19
# Proportion of T/sqrt(n) above 2 stds: 0.183
# P value = 0.000000
# Beta (=std): 13800
# Number of T/sqrt(n) above 3 stds: 11
# Proportion of T/sqrt(n) above 3 stds: 0.106
# P value = 0.000000
#
#
# Simulation without Adjustment Test Results
# Beta (=std): 13480
# Number of T/sqrt(n) above 2 stds: 19
# Proportion of T/sqrt(n) above 2 stds: 0.183
# P value = 0.000000
# Beta (=std): 13480
# Number of T/sqrt(n) above 3 stds: 12
# Proportion of T/sqrt(n) above 3 stds: 0.115
# P value = 0.000000
#
#
# Simulation WITH Adjustment Test Results
# Beta (=std): 13300
# Number of T/sqrt(n) above 2 stds: 21
# Proportion of T/sqrt(n) above 2 stds: 0.202
# P value = 0.000000
# Beta (=std): 13300
# Number of T/sqrt(n) above 3 stds: 12
# Proportion of T/sqrt(n) above 3 stds: 0.115
# P value = 0.000000

# %%
np.mean(beta_sims) * sum_sqrt_a * np.sqrt(2) / np.sqrt(np.pi)
# Out:
# 91608453.80616774

# %%
np.mean(beta_sim_adjs) * sum_sqrt_a * np.sqrt(2) / np.sqrt(np.pi)
# Out:
# 90385195.52092217

# %%
beta_sims
# Out:
# [13200, 12900, 13400, 13400, 14500]

# %%
beta_sim_adjs
# Out:
# [12800, 13400, 13200, 13600, 13500]
