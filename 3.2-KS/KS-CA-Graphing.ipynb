# %%
# %run ../StatTest2_WithSimulation_Setup.ipynb
# Out:
# {0: ['ME', 'IL', 'PA', 'GA', 'OK', 'DE', 'WA', 'CT', 'OH', 'VA', 'NE', 'MT', 'IN', 'CA', 'HI', 'ND', 'MD', 'SC', 'RI', 'AK', 'KY', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 1: ['SD', 'IL', 'PA', 'NH', 'NM', 'NV', 'OK', 'UT', 'CT', 'OH', 'VA', 'OR', 'CO', 'IN', 'HI', 'AL', 'RI', 'AK', 'LA', 'MN', 'IA', 'AR', 'WV'], 2: ['MI', 'ME', 'WY', 'DC', 'TX', 'AZ', 'NC', 'WA', 'OR', 'CO', 'MT', 'ND', 'TN', 'SC', 'AL', 'NY', 'KY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 3: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'GA', 'AZ', 'NM', 'NC', 'NV', 'DE', 'UT', 'NE', 'CA', 'MD', 'TN', 'NY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO']}
# {0: ['MI', 'SD', 'WY', 'NH', 'DC', 'TX', 'AZ', 'NM', 'NC', 'NV', 'UT', 'OR', 'CO', 'TN', 'AL', 'NY', 'NJ', 'KS', 'ID', 'IA', 'AR', 'MO'], 1: ['MI', 'ME', 'WY', 'DC', 'TX', 'GA', 'AZ', 'NC', 'DE', 'WA', 'NE', 'MT', 'CA', 'ND', 'MD', 'TN', 'SC', 'NY', 'KY', 'NJ', 'KS', 'WI', 'ID', 'MS', 'FL', 'MO'], 2: ['SD', 'IL', 'PA', 'NH', 'GA', 'NM', 'NV', 'OK', 'DE', 'UT', 'CT', 'OH', 'VA', 'NE', 'IN', 'CA', 'HI', 'MD', 'RI', 'AK', 'WI', 'LA', 'MN', 'MS', 'WV', 'FL'], 3: ['ME', 'IL', 'PA', 'OK', 'WA', 'CT', 'OH', 'VA', 'OR', 'CO', 'MT', 'IN', 'HI', 'ND', 'SC', 'AL', 'RI', 'AK', 'KY', 'LA', 'MN', 'IA', 'AR', 'WV']}

# %%
data2014 = pd.read_csv("../0-Our_Dataset/2014dataset.csv")
data2015 = pd.read_csv("../0-Our_Dataset/2015dataset.csv")
data2016 = pd.read_csv("../0-Our_Dataset/2016dataset.csv")
data2017 = pd.read_csv("../0-Our_Dataset/2017dataset.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,52,323,649,882,932,1092,1202) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,57,204,341,376,377,396,430,431,928,944,1006,1013,1151,1160,1169,1179,1411) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,17,163,355,406,702,835,847,1083,1156,1183,1185,1200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create the labels.
# By index:
# label 2 is transfers
# label 3 is premiums
# label 4 is costs
# label 5 is member months
# label 6 is reinsurance (individual group only)

ind_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                  "HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)",
                  "1.1Directpremiumwritten2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "2.16Totalincurredclaims2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "7.4Membermonths2HealthInsuranceINDIVIDUALTotalasof3/31/15",
                  "STATE", "REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)"] # no more reinsurance as of 2017
ind_labels_15 = [label.replace('15', '16') for label in ind_labels_14]
ind_labels_16 = [label.replace('15', '17') for label in ind_labels_14]
ind_labels_17 = [label.replace('15', '18') for label in ind_labels_14][:-1]

sg_labels_14 = ["HIOS ID", "HIOS INPUTTED INSURANCE COMPANY NAME",
                 "HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)",
                  "1.1Directpremiumwritten7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "2.16Totalincurredclaims7HealthInsuranceSMALLGROUPTotalasof3/31/15",
                  "7.4Membermonths7HealthInsuranceSMALLGROUPTotalasof3/31/15", "STATE"]
sg_labels_15 = [label.replace('15', '16') for label in sg_labels_14]
sg_labels_16 = [label.replace('15', '17') for label in sg_labels_14]
sg_labels_17 = [label.replace('15', '18') for label in sg_labels_14]

# %%
# Filter the data to include only the fields we want

ind_data_14 = data2014[ind_labels_14].dropna()
ind_data_15 = data2015[ind_labels_15].dropna()
ind_data_16 = data2016[ind_labels_16].dropna()
ind_data_17 = data2017[ind_labels_17].dropna()
sg_data_14 = data2014[sg_labels_14].dropna()
sg_data_15 = data2015[sg_labels_15].dropna()
sg_data_16 = data2016[sg_labels_16].dropna()
sg_data_17 = data2017[sg_labels_17].dropna()

# %%
# Drop companies with <2000 MM
ind_data_14 = ind_data_14.where(ind_data_14[ind_labels_14[5]] > 2000).dropna()
ind_data_15 = ind_data_15.where(ind_data_15[ind_labels_15[5]] > 2000).dropna()
ind_data_16 = ind_data_16.where(ind_data_16[ind_labels_16[5]] > 2000).dropna()
ind_data_17 = ind_data_17.where(ind_data_17[ind_labels_17[5]] > 2000).dropna()
sg_data_14 = sg_data_14.where(sg_data_14[sg_labels_14[5]] > 2000).dropna()
sg_data_15 = sg_data_15.where(sg_data_15[sg_labels_15[5]] > 2000).dropna()
sg_data_16 = sg_data_16.where(sg_data_16[sg_labels_16[5]] > 2000).dropna()
sg_data_17 = sg_data_17.where(sg_data_17[sg_labels_17[5]] > 2000).dropna()

# %%
# Calculate transfers, premiums, costs, and reinsurance (if individual group) per member month
def calculate_pmm(df, df_labels, group):
    df["MM"] = df[df_labels[5]]
    df["Transfers"] = df[df_labels[2]]
    df["TotalCosts"] = abs(df[df_labels[4]])
    df["Enrollees"] = df["MM"] / 12
    df["TransfersPerEnrollee"] = df["Transfers"] / df["Enrollees"]
    df["TransfersPerSqrtEnrollee"] = df["Transfers"] / np.sqrt(df["Enrollees"])
    df["LogEnrollees"] = np.log(df["Enrollees"])
    df["LogTransfers"] = np.log(df["Transfers"]**2 + 1)
    df["TransfersPMM"] = df[df_labels[2]] / df[df_labels[5]]
    df["PremiumsPMM"] = abs(df[df_labels[3]] / df[df_labels[5]])
    df["CostsPMM"] = abs(df[df_labels[4]] / df[df_labels[5]])
    if group == "i":
        df["ReinsurancePMM"] = df[df_labels[7]] / df[df_labels[5]]
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"] + df["ReinsurancePMM"]
        #df["PremMinusCostsPlusReinsurancePMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["ReinsurancePMM"]
    elif group == "sg":
        df["ProfitsPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["PremMinusCostsPMM"] = df["PremiumsPMM"] - df["CostsPMM"]
    df["PremMinusCostsPlusTransfersPMM"] = df["PremiumsPMM"] - df["CostsPMM"] + df["TransfersPMM"]
    df["SicknessPMM"] = df["CostsPMM"] - df["PremiumsPMM"]
    average_sickness = np.mean(df["SicknessPMM"])
    df["ExcessSicknessPMM"] = df["SicknessPMM"] - average_sickness
    return df

ind_data_14 = calculate_pmm(ind_data_14, ind_labels_14, "i")
ind_data_15 = calculate_pmm(ind_data_15, ind_labels_15, "i")
ind_data_16 = calculate_pmm(ind_data_16, ind_labels_16, "i")
ind_data_17 = calculate_pmm(ind_data_17, ind_labels_17, "sg")
sg_data_14 = calculate_pmm(sg_data_14, sg_labels_14, "sg")
sg_data_15 = calculate_pmm(sg_data_15, sg_labels_15, "sg")
sg_data_16 = calculate_pmm(sg_data_16, sg_labels_16, "sg")
sg_data_17 = calculate_pmm(sg_data_17, sg_labels_17, "sg")

# %%
# Combine the dataframes by left merging

ind_data = ind_data_14.merge(ind_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(ind_data_16, on='HIOS ID', how='outer').merge(ind_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
# Do the same thing for small group

sg_data = sg_data_14.merge(sg_data_15, on='HIOS ID', how='outer', suffixes=('_14', '_15'))\
.merge(sg_data_16, on='HIOS ID', how='outer').merge(sg_data_17, on='HIOS ID', how='outer', suffixes=('_16', '_17'))

# %%
states = ["CA"]
dfs = [sg_data_14, sg_data_15, sg_data_16, sg_data_17]

# %%
dfs_new, _ = normalize_empirical_data_to_avg_2017_dollars(dfs, states)
# Out:
# Cbar is 4398.953
# CA 14 Ratio is 1.154
# CA 15 Ratio is 1.117
# CA 16 Ratio is 1.051
# CA 17 Ratio is 1.015
# Empirical Transfers Sum = 2043400167.669

# %%
for df_temp in dfs_new:
    df_temp["TransfersNormalizedPerSqrtEnrollee"] = df_temp["TransfersNormalized"] / np.sqrt(df_temp["Enrollees"])

# %%
#dfs_new[3][["TransfersPerSqrtEnrollee", "TransfersNormalizedPerSqrtEnrollee"]]

# %%
df2 = create_df2(states, dfs_new, "TransfersNormalizedPerSqrtEnrollee")

# %%
k = len(df2)
v = np.linspace(0, max(abs(df2)), 10000)
v = v[1:len(v)]

ratios = [ratio_list(df2, vi) for vi in v]
#print(ratios)
begin_p = 5/k
end_p = 1-begin_p
start_index = 0
end_index = 0
for index, ratio2 in enumerate(ratios):
    if ratio2 >= begin_p:
        start_index = index
        break
    
for index, ratio2 in enumerate(ratios):
    if ratio2 > end_p:
        end_index = index
        break

if end_index == 0:
    end_index = len(v) - 1
    
v = v[start_index:end_index]

ratios2 = ratios[start_index:end_index]
multiplier = [np.sqrt(2)/vi for vi in v]
#plt.plot(v, ratios2)
#plt.plot(v, multiplier)

# %%
y = [multiplier[i] * special.erfinv(ratio2) for i, ratio2 in enumerate(ratios2)]
#plt.plot(v, y)
#plt.title("1/beta vs. v")
beta = [1/yi for yi in y]
#plt.plot(v, beta)
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
#plt.title("beta vs. v")

# %%
# Finding the minimum beta
# Whenever we reject a beta, we reject all betas greater than that,
# so keep pushing beta smaller until we reach max_difference == test_statistic
# Run test for larger data sizes (combining states, years)

# %%
max_beta=max(beta)
max_beta = int(max_beta/100)*100

# %%
theoretical = [special.erf(vi/(max_beta*np.sqrt(2))) for vi in v]

plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v)")
plt.plot(v, ratios2, label="P(|d_i|<v)")
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (states, len(df2)))
#plt.axvline(x=64432.69, color='r', linestyle='--', label="Point of max difference")
plt.legend()
print("beta = %.3f" % (max_beta))
# Out:
# beta = 122700.000

# %%
beta_theoretical, Mb_index = run_test_against_theoretical(df2, max_beta, ratios2, False)
# Out:
# k = 61
# test_stat at this k = 0.15385
#
# At the point of maximum difference with beta = 122700:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.3225
# Difference = 0.2676
#
#
#
#
# At the point of maximum difference with beta = 112700:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.3493
# Difference = 0.2408
#
#
#
#
# At the point of maximum difference with beta = 102700:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.3808
# Difference = 0.2094
#
#
#
#
# At the point of maximum difference with beta = 92700:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2821
# Difference = 0.1770
#
#
#
#
# At the point of maximum difference with beta = 92700:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2821
# Difference = 0.1770
#
#
#
#
# At the point of maximum difference with beta = 92600:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2823
# Difference = 0.1767
#
#
#
#
# At the point of maximum difference with beta = 92500:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2826
# Difference = 0.1764
#
#
#
#
# At the point of maximum difference with beta = 92400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2829
# Difference = 0.1761
#
#
#
#
# At the point of maximum difference with beta = 92300:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2832
# Difference = 0.1758
#
#
#
#
# At the point of maximum difference with beta = 92200:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2835
# Difference = 0.1755
#
#
#
#
# At the point of maximum difference with beta = 92100:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2838
# Difference = 0.1752
#
#
#
#
# At the point of maximum difference with beta = 92000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2841
# Difference = 0.1749
#
#
#
#
# At the point of maximum difference with beta = 91900:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2844
# Difference = 0.1746
#
#
#
#
# At the point of maximum difference with beta = 91800:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2847
# Difference = 0.1743
#
#
#
#
# At the point of maximum difference with beta = 91700:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2850
# Difference = 0.1740
#
#
#
#
# At the point of maximum difference with beta = 91600:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2853
# Difference = 0.1737
#
#
#
#
# At the point of maximum difference with beta = 91500:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2856
# Difference = 0.1734
#
#
#
#
# At the point of maximum difference with beta = 91400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2859
# Difference = 0.1731
#
#
#
#
# At the point of maximum difference with beta = 91300:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2862
# Difference = 0.1728
#
#
#
#
# At the point of maximum difference with beta = 91200:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2865
# Difference = 0.1725
#
#
#
#
# At the point of maximum difference with beta = 91100:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2868
# Difference = 0.1722
#
#
#
#
# At the point of maximum difference with beta = 91000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2871
# Difference = 0.1719
#
#
#
#
# At the point of maximum difference with beta = 90900:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2874
# Difference = 0.1716
#
#
#
#
# At the point of maximum difference with beta = 90800:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2877
# Difference = 0.1713
#
#
#
#
# At the point of maximum difference with beta = 90700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2388
# Difference = 0.1711
#
#
#
#
# At the point of maximum difference with beta = 90600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2390
# Difference = 0.1708
#
#
#
#
# At the point of maximum difference with beta = 90500:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2393
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 90400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2396
# Difference = 0.1703
#
#
#
#
# At the point of maximum difference with beta = 90300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2398
# Difference = 0.1700
#
#
#
#
# At the point of maximum difference with beta = 90200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2401
# Difference = 0.1698
#
#
#
#
# At the point of maximum difference with beta = 90100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2403
# Difference = 0.1695
#
#
#
#
# At the point of maximum difference with beta = 90000:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2406
# Difference = 0.1693
#
#
#
#
# At the point of maximum difference with beta = 89900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2408
# Difference = 0.1690
#
#
#
#
# At the point of maximum difference with beta = 89800:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2411
# Difference = 0.1687
#
#
#
#
# At the point of maximum difference with beta = 89700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2414
# Difference = 0.1685
#
#
#
#
# At the point of maximum difference with beta = 89600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2416
# Difference = 0.1682
#
#
#
#
# At the point of maximum difference with beta = 89500:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2419
# Difference = 0.1679
#
#
#
#
# At the point of maximum difference with beta = 89400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2421
# Difference = 0.1677
#
#
#
#
# At the point of maximum difference with beta = 89300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2424
# Difference = 0.1674
#
#
#
#
# At the point of maximum difference with beta = 89200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2427
# Difference = 0.1672
#
#
#
#
# At the point of maximum difference with beta = 89100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2429
# Difference = 0.1669
#
#
#
#
# At the point of maximum difference with beta = 89000:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2432
# Difference = 0.1666
#
#
#
#
# At the point of maximum difference with beta = 88900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2435
# Difference = 0.1664
#
#
#
#
# At the point of maximum difference with beta = 88800:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2437
# Difference = 0.1661
#
#
#
#
# At the point of maximum difference with beta = 88700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2440
# Difference = 0.1658
#
#
#
#
# At the point of maximum difference with beta = 88600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2443
# Difference = 0.1656
#
#
#
#
# At the point of maximum difference with beta = 88500:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2445
# Difference = 0.1653
#
#
#
#
# At the point of maximum difference with beta = 88400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2448
# Difference = 0.1650
#
#
#
#
# At the point of maximum difference with beta = 88300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2451
# Difference = 0.1648
#
#
#
#
# At the point of maximum difference with beta = 88200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2453
# Difference = 0.1645
#
#
#
#
# At the point of maximum difference with beta = 88100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2456
# Difference = 0.1642
#
#
#
#
# At the point of maximum difference with beta = 88000:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2459
# Difference = 0.1640
#
#
#
#
# At the point of maximum difference with beta = 87900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2461
# Difference = 0.1637
#
#
#
#
# At the point of maximum difference with beta = 87800:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2464
# Difference = 0.1634
#
#
#
#
# At the point of maximum difference with beta = 87700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2467
# Difference = 0.1631
#
#
#
#
# At the point of maximum difference with beta = 87600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2470
# Difference = 0.1629
#
#
#
#
# At the point of maximum difference with beta = 87500:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2472
# Difference = 0.1626
#
#
#
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2475
# Difference = 0.1623
#
#
#
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2478
# Difference = 0.1621
#
#
#
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2481
# Difference = 0.1618
#
#
#
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2483
# Difference = 0.1615
#
#
#
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2486
# Difference = 0.1612
#
#
#
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2489
# Difference = 0.1609
#
#
#
#
# At the point of maximum difference with beta = 86800:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2492
# Difference = 0.1607
#
#
#
#
# At the point of maximum difference with beta = 86700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2494
# Difference = 0.1604
#
#
#
#
# At the point of maximum difference with beta = 86600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2497
# Difference = 0.1601
#
#
#
#
# At the point of maximum difference with beta = 86500:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2500
# Difference = 0.1598
#
#
#
#
# At the point of maximum difference with beta = 86400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2503
# Difference = 0.1596
#
#
#
#
# At the point of maximum difference with beta = 86300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2506
# Difference = 0.1593
#
#
#
#
# At the point of maximum difference with beta = 86200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2508
# Difference = 0.1590
# At the point of maximum difference with beta = 86100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1527
# Difference = 0.1588
#
#
#
#
# At the point of maximum difference with beta = 86000:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1529
# Difference = 0.1586
#
#
#
#
# At the point of maximum difference with beta = 85900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1531
# Difference = 0.1584
#
#
#
#
# At the point of maximum difference with beta = 85800:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1532
# Difference = 0.1582
#
#
#
#
# At the point of maximum difference with beta = 85700:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1534
# Difference = 0.1581
#
#
#
#
# At the point of maximum difference with beta = 85600:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1536
# Difference = 0.1579
#
#
#
#
# At the point of maximum difference with beta = 85500:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1538
# Difference = 0.1577
#
#
#
#
# At the point of maximum difference with beta = 85400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1539
# Difference = 0.1575
#
#
#
#
# At the point of maximum difference with beta = 85300:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1541
# Difference = 0.1574
#
#
#
#
# At the point of maximum difference with beta = 85200:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1543
# Difference = 0.1572
#
#
#
#
# At the point of maximum difference with beta = 85100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1545
# Difference = 0.1570
#
#
#
#
# At the point of maximum difference with beta = 85000:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1547
# Difference = 0.1568
#
#
#
#
# At the point of maximum difference with beta = 84900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1548
# Difference = 0.1566
#
#
#
#
# At the point of maximum difference with beta = 84800:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1550
# Difference = 0.1565
#
#
#
#
# At the point of maximum difference with beta = 84700:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1552
# Difference = 0.1563
#
#
#
#
# At the point of maximum difference with beta = 84600:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1554
# Difference = 0.1561
#
#
#
#
# At the point of maximum difference with beta = 84500:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1556
# Difference = 0.1559
#
#
#
#
# At the point of maximum difference with beta = 84400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1557
# Difference = 0.1557
#
#
#
#
# At the point of maximum difference with beta = 84300:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1559
# Difference = 0.1555
#
#
#
#
# At the point of maximum difference with beta = 84200:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1561
# Difference = 0.1554
#
#
#
#
# At the point of maximum difference with beta = 84100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1563
# Difference = 0.1552
#
#
#
#
# At the point of maximum difference with beta = 84000:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1565
# Difference = 0.1550
#
#
#
#
# At the point of maximum difference with beta = 83900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1567
# Difference = 0.1548
#
#
#
#
# At the point of maximum difference with beta = 83800:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1568
# Difference = 0.1546
#
#
#
#
# At the point of maximum difference with beta = 83700:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1570
# Difference = 0.1544
#
#
#
#
# At the point of maximum difference with beta = 83600:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1572
# Difference = 0.1543
#
#
#
#
# At the point of maximum difference with beta = 83500:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1574
# Difference = 0.1541
#
#
#
#
# At the point of maximum difference with beta = 83400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1576
# Difference = 0.1539

# %%
theoretical1 = [special.erf(vi/(60000*np.sqrt(2))) for vi in v]
theoretical2 = [special.erf(vi/(80000*np.sqrt(2))) for vi in v]
theoretical3 = [special.erf(vi/(100000*np.sqrt(2))) for vi in v]

state_label = "CA"
plt.figure(figsize=(8, 6))
plt.plot(v, theoretical1, label="P(|N(0,beta^2)|<v) beta=60,000", color='b')
plt.plot(v, theoretical2, label="P(|N(0,beta^2)|<v) beta=80,000", color='c')
plt.plot(v, theoretical3, label="P(|N(0,beta^2)|<v) beta=100,000", color='cornflowerblue')
plt.plot(v, ratios2, label="P(|d_i|<v)", color='darkorange')
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
#plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference")
plt.legend()
plt.xlabel("v")
plt.ylabel("CDF")
plt.show()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
theoretical = [special.erf(vi/(83400*np.sqrt(2))) for vi in v]

state_label = "CA"
plt.figure(figsize=(8, 6))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) beta=83,400", color='b')
plt.plot(v, ratios2, label="P(|d_i|<v)", color='darkorange')
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s 2014-2017 (k=%d)" % (state_label, len(df2)))
plt.axvline(x=v[Mb_index], color='r', linestyle='--', label="Point of max difference (empirical-theoretical)")
plt.legend()
plt.xlabel("v")
plt.ylabel("CDF")
plt.show()
#plt.xlim(0, 50000)
#print("beta = %.3f" % (max_beta))

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 83400
# Number of T/sqrt(n) above 2 stds: 7
# Proportion of T/sqrt(n) above 2 stds: 0.115
# P value = 0.006278

# %%
ratios_c, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical - 10000)
ratios_c2, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical)
ratios_c3, _ = create_simulation_adjust_for_imbalances(states, dfs_new, beta_theoretical + 10000)
# Out:
# Sum sqrt(a) = 14920.576
# Sum sqrt(a) = 14920.576
# Sum sqrt(a) = 14920.576

# %%
theoretical = [special.erf(vi/(beta_theoretical*np.sqrt(2))) for vi in v]

plt.figure(figsize=(10, 7))
plt.plot(v, theoretical, label="P(|N(0,beta^2)|<v) with beta = %d" % (beta_theoretical))
plt.plot(v, ratios2, label="P(|d_i|<v) = empirical distribution")
plt.plot(v, ratios_c, label="Simulation with es = %d, 5 times" % (beta_theoretical - 10000))
plt.plot(v, ratios_c2, label="Simulation with es = %d, 5 times" % (beta_theoretical))
plt.plot(v, ratios_c3, label="Simulation with es = %d, 5 times" % (beta_theoretical + 10000))
plt.title("P(|N(0,beta^2)|<v) and P(|d_i|<v) vs. v for %s (k=%d)" % (states, len(df2)))
plt.legend()

# %%
beta_sims = list()

for i in range(5):
    beta_sim, _= run_test_against_simulation(states, dfs_new, beta_theoretical, ratios2, False)
    beta_sims.append(beta_sim)
# Out:
# k = 61
# test_stat at this k = 0.15385
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2732
# Difference = 0.1858
#
#
#
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2820
# Difference = 0.1770
#
#
#
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1388
# Difference = 0.1727
#
#
#
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1486
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2754
# Difference = 0.1836
#
#
#
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2197
# Difference = 0.1902
#
#
#
#
# At the point of maximum difference with beta = 86800:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4164
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 86700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2317
# Difference = 0.1781
#
#
#
#
# At the point of maximum difference with beta = 86600:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4164
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 86500:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1749
# Difference = 0.1366 NOT > test_stat
# k = 61
# test_stat at this k = 0.15385
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2809
# Difference = 0.1781
#
#
#
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2863
# Difference = 0.1727
#
#
#
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4131
# Difference = 0.1770
#
#
#
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2656
# Difference = 0.1443 NOT > test_stat
# k = 61
# test_stat at this k = 0.15385
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.3770
# Difference = 0.2131
#
#
#
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2678
# Difference = 0.1913
#
#
#
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.3005
# Difference = 0.1585
#
#
#
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1464
# Difference = 0.1650
#
#
#
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.3148
# Difference = 0.1443 NOT > test_stat
# k = 61
# test_stat at this k = 0.15385
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2634
# Difference = 0.1956
#
#
#
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.3956
# Difference = 0.1945
#
#
#
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2852
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1388
# Difference = 0.1727
#
#
#
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2393
# Difference = 0.1705
#
#
#
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.5410
# P(|N(0,max_beta^2)|<v) = 0.3541
# Difference = 0.1869
#
#
#
#
# At the point of maximum difference with beta = 86800:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2470
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 86700:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2896
# Difference = 0.1694
#
#
#
#
# At the point of maximum difference with beta = 86600:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2634
# Difference = 0.1956
#
#
#
#
# At the point of maximum difference with beta = 86500:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1366
# Difference = 0.1749
#
#
#
#
# At the point of maximum difference with beta = 86400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2743
# Difference = 0.1847
#
#
#
#
# At the point of maximum difference with beta = 86300:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2918
# Difference = 0.1672
#
#
#
#
# At the point of maximum difference with beta = 86200:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2372
# Difference = 0.1891
#
#
#
#
# At the point of maximum difference with beta = 86100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1311
# Difference = 0.1803
#
#
#
#
# At the point of maximum difference with beta = 86000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2754
# Difference = 0.1836
#
#
#
#
# At the point of maximum difference with beta = 85900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2240
# Difference = 0.1858
#
#
#
#
# At the point of maximum difference with beta = 85800:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2721
# Difference = 0.1377 NOT > test_stat
# k = 61
# test_stat at this k = 0.15385
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2470
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2372
# Difference = 0.1891
#
#
#
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4273
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2678
# Difference = 0.1913
#
#
#
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2437
# Difference = 0.1661
#
#
#
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.5246
# P(|N(0,max_beta^2)|<v) = 0.3585
# Difference = 0.1661
#
#
#
#
# At the point of maximum difference with beta = 86800:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4044
# Difference = 0.1858
#
#
#
#
# At the point of maximum difference with beta = 86700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2404
# Difference = 0.1694
#
#
#
#
# At the point of maximum difference with beta = 86600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2459
# Difference = 0.1639
#
#
#
#
# At the point of maximum difference with beta = 86500:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2918
# Difference = 0.1672
#
#
#
#
# At the point of maximum difference with beta = 86400:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2689
# Difference = 0.1574
#
#
#
#
# At the point of maximum difference with beta = 86300:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1454
# Difference = 0.1661
#
#
#
#
# At the point of maximum difference with beta = 86200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2251
# Difference = 0.1847
#
#
#
#
# At the point of maximum difference with beta = 86100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2240
# Difference = 0.1858
#
#
#
#
# At the point of maximum difference with beta = 86000:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4153
# Difference = 0.1749
#
#
#
#
# At the point of maximum difference with beta = 85900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1486
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 85800:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2623
# Difference = 0.1967
#
#
#
#
# At the point of maximum difference with beta = 85700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2328
# Difference = 0.1770
#
#
#
#
# At the point of maximum difference with beta = 85600:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2426
# Difference = 0.1836
#
#
#
#
# At the point of maximum difference with beta = 85500:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1235
# Difference = 0.1880
#
#
#
#
# At the point of maximum difference with beta = 85400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1377
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 85300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2262
# Difference = 0.1836
#
#
#
#
# At the point of maximum difference with beta = 85200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2361
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 85100:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2918
# Difference = 0.1672
#
#
#
#
# At the point of maximum difference with beta = 85000:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4350
# Difference = 0.1552
#
#
#
#
# At the point of maximum difference with beta = 84900:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2383
# Difference = 0.1716
# At the point of maximum difference with beta = 84800:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1486
# Difference = 0.1628
#
#
#
#
# At the point of maximum difference with beta = 84700:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1432
# Difference = 0.1683
#
#
#
#
# At the point of maximum difference with beta = 84600:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1377
# Difference = 0.1738
#
#
#
#
# At the point of maximum difference with beta = 84500:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2393
# Difference = 0.1869
#
#
#
#
# At the point of maximum difference with beta = 84400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2546
# Difference = 0.1552
#
#
#
#
# At the point of maximum difference with beta = 84300:
# P(|d_i|<v) = 0.2951
# P(|N(0,max_beta^2)|<v) = 0.1344
# Difference = 0.1607
#
#
#
#
# At the point of maximum difference with beta = 84200:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1421
# Difference = 0.1694
#
#
#
#
# At the point of maximum difference with beta = 84100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2372
# Difference = 0.1727
#
#
#
#
# At the point of maximum difference with beta = 84000:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4328
# Difference = 0.1574
#
#
#
#
# At the point of maximum difference with beta = 83900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1563
# Difference = 0.1552
#
#
#
#
# At the point of maximum difference with beta = 83800:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1454
# Difference = 0.1661
#
#
#
#
# At the point of maximum difference with beta = 83700:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2699
# Difference = 0.1563
#
#
#
#
# At the point of maximum difference with beta = 83600:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1530
# Difference = 0.1585
#
#
#
#
# At the point of maximum difference with beta = 83500:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2874
# Difference = 0.1716
#
#
#
#
# At the point of maximum difference with beta = 83400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1661
# Difference = 0.1454 NOT > test_stat

# %%
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
# Out:
# Simulation without Adjustment Test Results
# Beta (=std): 85960
# Number of T/sqrt(n) above 2 stds: 7
# Proportion of T/sqrt(n) above 2 stds: 0.115
# P value = 0.006278
# Beta (=std): 85960
# Number of T/sqrt(n) above 3 stds: 4
# Proportion of T/sqrt(n) above 3 stds: 0.066
# P value = 0.000001

# %%
beta_sim_adjs = list()

for i in range(5):
    beta_sim_adj, _= run_test_against_simulation_adjust_for_imbalances(states, dfs_new,
                                                                   beta_theoretical, ratios2, False)
    beta_sim_adjs.append(beta_sim_adj)
# Out:
# k = 61
# test_stat at this k = 0.15385
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1366
# Difference = 0.1749
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1486
# Difference = 0.1628
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2361
# Difference = 0.1738
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2525
# Difference = 0.1574
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4426
# P(|N(0,max_beta^2)|<v) = 0.2656
# Difference = 0.1770
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.3137
# Difference = 0.1454 NOT > test_stat
# E(|X|) = 1034535574.267
# k = 61
# test_stat at this k = 0.15385
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1410
# Difference = 0.1705
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2459
# Difference = 0.1803
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.2951
# P(|N(0,max_beta^2)|<v) = 0.1235
# Difference = 0.1716
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1650
# Difference = 0.1464 NOT > test_stat
# E(|X|) = 1036916553.725
# k = 61
# test_stat at this k = 0.15385
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2852
# Difference = 0.1738
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2525
# Difference = 0.1574
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1443
# Difference = 0.1672
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2273
# Difference = 0.1825
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1366
# Difference = 0.1749
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1464
# Difference = 0.1650
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86800:
# P(|d_i|<v) = 0.4262
# P(|N(0,max_beta^2)|<v) = 0.2328
# Difference = 0.1934
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86700:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1541
# Difference = 0.1574
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86600:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2219
# Difference = 0.1880
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86500:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2896
# Difference = 0.1694
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2448
# Difference = 0.1650
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2240
# Difference = 0.1858
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86200:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2962
# Difference = 0.1628
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86100:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2295
# Difference = 0.1803
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2973
# Difference = 0.1617
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 85900:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1377
# Difference = 0.1738
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 85800:
# P(|d_i|<v) = 0.5410
# P(|N(0,max_beta^2)|<v) = 0.3792
# Difference = 0.1617
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 85700:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2383
# Difference = 0.1716
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 85600:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1355
# Difference = 0.1760
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 85500:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2404
# Difference = 0.1694
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 85400:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4481
# Difference = 0.1421 NOT > test_stat
# E(|X|) = 1016678228.336
# k = 61
# test_stat at this k = 0.15385
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2525
# Difference = 0.1574
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.3115
# P(|N(0,max_beta^2)|<v) = 0.1497
# Difference = 0.1617
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2284
# Difference = 0.1814
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87100:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2798
# Difference = 0.1792
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87000:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2743
# Difference = 0.1847
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86900:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4251
# Difference = 0.1650
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86800:
# P(|d_i|<v) = 0.5902
# P(|N(0,max_beta^2)|<v) = 0.4262
# Difference = 0.1639
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 86700:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.3148
# Difference = 0.1443 NOT > test_stat
# E(|X|) = 1032154594.810
# k = 61
# test_stat at this k = 0.15385
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87400:
# P(|d_i|<v) = 0.4590
# P(|N(0,max_beta^2)|<v) = 0.2940
# Difference = 0.1650
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87300:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2350
# Difference = 0.1749
#
#
#
# Sum sqrt(a) = 14920.576
#
# At the point of maximum difference with beta = 87200:
# P(|d_i|<v) = 0.4098
# P(|N(0,max_beta^2)|<v) = 0.2590
# Difference = 0.1508 NOT > test_stat
# E(|X|) = 1038107043.454

# %%
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Simulation WITH Adjustment Test Results
# Beta (=std): 86660
# Number of T/sqrt(n) above 2 stds: 7
# Proportion of T/sqrt(n) above 2 stds: 0.115
# P value = 0.006278
# Beta (=std): 86660
# Number of T/sqrt(n) above 3 stds: 4
# Proportion of T/sqrt(n) above 3 stds: 0.066
# P value = 0.000001

# %%
print("Theoretical Test Results")
run_binom_stat_test2(beta_theoretical, df2.values)
run_binom_stat_test3(beta_theoretical, df2.values)
print("\n")
print("Simulation without Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sims), df2.values)
run_binom_stat_test3(np.mean(beta_sims), df2.values)
print("\n")
print("Simulation WITH Adjustment Test Results")
run_binom_stat_test2(np.mean(beta_sim_adjs), df2.values)
run_binom_stat_test3(np.mean(beta_sim_adjs), df2.values)
# Out:
# Theoretical Test Results
# Beta (=std): 83400
# Number of T/sqrt(n) above 2 stds: 7
# Proportion of T/sqrt(n) above 2 stds: 0.115
# P value = 0.006278
# Beta (=std): 83400
# Number of T/sqrt(n) above 3 stds: 4
# Proportion of T/sqrt(n) above 3 stds: 0.066
# P value = 0.000001
#
#
# Simulation without Adjustment Test Results
# Beta (=std): 85960
# Number of T/sqrt(n) above 2 stds: 7
# Proportion of T/sqrt(n) above 2 stds: 0.115
# P value = 0.006278
# Beta (=std): 85960
# Number of T/sqrt(n) above 3 stds: 4
# Proportion of T/sqrt(n) above 3 stds: 0.066
# P value = 0.000001
#
#
# Simulation WITH Adjustment Test Results
# Beta (=std): 86660
# Number of T/sqrt(n) above 2 stds: 7
# Proportion of T/sqrt(n) above 2 stds: 0.115
# P value = 0.006278
# Beta (=std): 86660
# Number of T/sqrt(n) above 3 stds: 4
# Proportion of T/sqrt(n) above 3 stds: 0.066
# P value = 0.000001

# %%
x = np.linspace(0, 3)
plt.figure(figsize=(8, 5))
plt.plot(x, special.erf(x), label="P(|N(0,0.5)|<x)", color='b')
plt.plot(x, special.erf(x / np.sqrt(2)), label="P(|N(0,1)|<x)", color='c')
plt.title("|N(0,0.5)| Stochastically Dominates |N(0,1)|")
plt.legend()
plt.xlabel("x")
plt.ylabel("CDF")
plt.show()
plt.show()
